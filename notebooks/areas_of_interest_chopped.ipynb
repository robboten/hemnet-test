# %%
import json
import os

from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd
from pathlib import Path
import requests
import yaml

# %%
# Current utc date and time
utcnow = datetime.utcnow().strftime("%Y%m%d_%H%M")
dateoftoday = datetime.utcnow().strftime("%Y%m%d")

# %%
# Create a folder for all the files

# Parent directory path
parent_dir_path = "../data/areas_of_interest/"

# Directory path
directory_path = f"{parent_dir_path}{utcnow}/"

# Create the directory path in os
Path(directory_path).mkdir(parents=True, exist_ok=True)

# %%
# Read the areas and their hemnet area code from config
with open("../configs/area_ids.yaml", "r") as stream:
    area_info = yaml.safe_load(stream)

# %% [markdown]
# p="../configs/area_ids.json"
# with open(p, 'r') as f:
#   area_info = json.load(f)
#
# area_info

# %% [markdown]
# locations_url=""
#
# for area in area_info:
#     area_code = area_info[area]["area_code"]
#     locations_url=locations_url+f"location_ids[]={area_code}&"
#
# locations_url

# %% [markdown]
# #import urllib.parse

# %%
p="../configs/area_ids.json"
with open(p, 'r') as f:
  area_info = json.load(f)

area_info
map_keys={}
url = "https://www.hemnet.se/bostader"
payload={}
headers = {"User-Agent": "Mozilla/5.0"}
for area in area_info:
    area_code = area_info[area]["area_code"]
    print(area_code)

    # Start the process of scaring
    params= {
        "housing_form_groups":"apartments",
        "location_ids":area_code,
        "item_types":"bostadsratt",
        "rooms_min":0,
        "living_area_min":0,
        "new_construction":"include"
    } 

    response = requests.request(
        "GET",
        url,
        params=params,
        headers=headers
    )
    #print(response.url)

    soup = BeautifulSoup(response.content, "html.parser")
    map_results=soup.find(id="results-map")

    initial_data=map_results.attrs["data-initial-data"]
    json_data=json.loads(initial_data)

    #print(json_data)

    map_keys[area]=json_data['search_key']

json_map_keys=json.dumps(map_keys,sort_keys=True, indent=4)

with open(f"../configs/area_map_ids.json", "w") as file_out:
    file_out.write(json_map_keys)
# Out:
# 473397
# 898475
# 473369
# 925968
# 473448
# 473422
# 473386
# 898472
# 925970
# 925969
# 18042
# 18028
# 473362

# %%
import urllib.parse

# %%
params= {
    "housing_form_groups":"apartments",
    #"location_ids":area_code,
    "item_types":"bostadsratt",
    "rooms_min":0,
    "living_area_min":0,
    "new_construction":"include"
}

# %%
req_url=url+"?"+locations_url+urllib.parse.urlencode(params)
#url=url++locations_url
req_url
# Out:
# 'https://www.hemnet.se/bostader?location_ids[]=473397&location_ids[]=898475&location_ids[]=473369&location_ids[]=925968&location_ids[]=473448&location_ids[]=473422&location_ids[]=473386&location_ids[]=898472&location_ids[]=925970&location_ids[]=925969&location_ids[]=18042&location_ids[]=18028&location_ids[]=473362&housing_form_groups=apartments&item_types=bostadsratt&rooms_min=0&living_area_min=0&new_construction=include'

# %%
req_url="https://www.hemnet.se/bostader?location_ids[]=473397&housing_form_groups=apartments&item_types=bostadsratt&rooms_min=0&living_area_min=0&new_construction=include"

# %%
# Varible to keep the count of the listings.    
listings_count = 0
    
# Loop thruogh all the areas one by one
#for area in area_info:
#    area_code = area_info[area]["area_code"]

payload={}
headers = {"User-Agent": "Mozilla/5.0"}

response = requests.request(
    "GET",
    url=req_url,
    headers=headers
)

# %%
response.url
# Out:
# 'https://www.hemnet.se/bostader?location_ids%5B%5D=473397&housing_form_groups=apartments&item_types=bostadsratt&rooms_min=0&living_area_min=0&new_construction=include'

# %%
#response.content

# %%
soup = BeautifulSoup(response.content, "html.parser")
map_results=soup.find(id="results-map")
map_results
# Out:
# <div class="js-results-map property-map property-map--loading property-map--results property-map--attached-top" data-initial-data='{"project_ads":[{"id":3895,"coordinate":["59.35804","18.1009"],"project":true,"upcoming":true,"title":"Kanalliv i Norra Djurgårdsstaden","name":"Kolkajen","rooms":"1-4 rum","scope":"54 lägenheter","small_image_url":"https://bilder.hemnet.se/images/itemgallery_S/f6/fe/f6fe6216ddf26aaeaeee8b0863e8a10e.jpg","medium_image_url":"https://bilder.hemnet.se/images/itemgallery_M/f6/fe/f6fe6216ddf26aaeaeee8b0863e8a10e.jpg","url":"https://www.sernekebostad.se/kolkajen?utm_source=hemnet\u0026utm_medium=projekt\u0026utm_campaign=hemnet_kolkajen\u0026utm_content=hemnet","iconName":"bostadsratt","occupation_date":"","area":"Norra Djurgårdsstaden - Gärdet - Hjorthagen - Norra Djurgården","broker_logo_url":"https://bilder.hemnet.se/images/broker_logo_1/39/0e/390e6486a047392f3592dea9a67395af.jpg"},{"id":3739,"coordinate":["59.35648","18.090052"],"project":true,"upcoming":true,"title":"Bli medlem i OBOS och få förtur i Stadsljus","name":"Stadsljus","rooms":"0 rum","scope":"320 lägenheter","small_image_url":"https://bilder.hemnet.se/images/itemgallery_S/54/63/5463061f2f13ca1d67f1f703cd4e27a2.jpg","medium_image_url":"https://bilder.hemnet.se/images/itemgallery_M/54/63/5463061f2f13ca1d67f1f703cd4e27a2.jpg","url":"https://obos.se/hitta-bostad/sok-bostad/stockholm/stockholm/stadsljus/?utm_source=hemnet.se\u0026utm_medium=referral\u0026utm_campaign=stadsljus\u0026utm_content=kommandenyproduktion","iconName":"bostadsratt","occupation_date":"","area":"Norra Djurgårdsstaden - Gärdet - Hjorthagen - Norra Djurgården","broker_logo_url":"https://bilder.hemnet.se/images/broker_logo_1/bf/8b/bf8bf78f332488b3d4780e860397e4f5.png"}],"status":"for_sale","search_key":"91d4716f82833881428eaf46da90871b616396b3","locations":[473397],"assets_prefix":"","tileserver_host":"https://tiles.hemnet.se","map_url":"https://maps.googleapis.com/maps/api/js?key=AIzaSyAvR8lQbyQytYdggFUVGZekvRFX2fJGGZ0\u0026language=sv\u0026libraries=geometry%2Cplaces\u0026map_ids=f2115f301367545e\u0026region=SE\u0026v=weekly"}' data-search-map-context="resultlist" data-search-type="for_sale" id="results-map">
# <div class="property-map__update-message hcl-content-area hcl-content-area--on-map-or-image">
# <div class="hcl-padded-container hcl-padded-container--size-1">
# <i class="fa fa-refresh fa-spin"></i> Uppdaterar resultat
#     </div>
# </div>
# <ul class="property-map-controls hcl-stack">
# <li class="hcl-stack__item shrink-map">
# <a class="hcl-button hcl-button--secondary" href="#" onclick="hnt.ga('karta objektlista', 'mindre karta');"><span class="hcl-icon hcl-icon--inline fa fa-compress no-label"></span><span class="hide-element">Mindre karta</span></a>
# </li>
# <li class="hcl-stack__item enlarge-map">
# <a class="hcl-button hcl-button--secondary" href="#" onclick="hnt.ga('karta objektlista', 'storre karta');"><span class="hcl-icon hcl-icon--inline fa fa-expand no-label"></span><span class="hide-element">Större karta</span></a>
# </li>
# <li class="hcl-stack__item">
# <a class="hcl-button hcl-button--secondary" href="/bostader/karta?living_area_min=0&amp;location_ids%5B%5D=473397&amp;rooms_min=0" onclick="hnt.ga('karta objektlista', 'fullskarm');">
# <span class="hcl-icon hcl-icon--inline fa fa-map-o"></span> Karta i fullskärm
# </a> </li>
# </ul>
# <div class="property-map-container" id="map"></div>
# </div>

# %%
initial_data=map_results.attrs["data-initial-data"]
json_data=json.loads(initial_data)
json_data
# Out:
# {'project_ads': [{'id': 3895,
#    'coordinate': ['59.35804', '18.1009'],
#    'project': True,
#    'upcoming': True,
#    'title': 'Kanalliv i Norra Djurgårdsstaden',
#    'name': 'Kolkajen',
#    'rooms': '1-4 rum',
#    'scope': '54 lägenheter',
#    'small_image_url': 'https://bilder.hemnet.se/images/itemgallery_S/f6/fe/f6fe6216ddf26aaeaeee8b0863e8a10e.jpg',
#    'medium_image_url': 'https://bilder.hemnet.se/images/itemgallery_M/f6/fe/f6fe6216ddf26aaeaeee8b0863e8a10e.jpg',
#    'url': 'https://www.sernekebostad.se/kolkajen?utm_source=hemnet&utm_medium=projekt&utm_campaign=hemnet_kolkajen&utm_content=hemnet',
#    'iconName': 'bostadsratt',
#    'occupation_date': '',
#    'area': 'Norra Djurgårdsstaden - Gärdet - Hjorthagen - Norra Djurgården',
#    'broker_logo_url': 'https://bilder.hemnet.se/images/broker_logo_1/39/0e/390e6486a047392f3592dea9a67395af.jpg'},
#   {'id': 3739,
#    'coordinate': ['59.35648', '18.090052'],
#    'project': True,
#    'upcoming': True,
#    'title': 'Bli medlem i OBOS och få förtur i Stadsljus',
#    'name': 'Stadsljus',
#    'rooms': '0 rum',
#    'scope': '320 lägenheter',
#    'small_image_url': 'https://bilder.hemnet.se/images/itemgallery_S/54/63/5463061f2f13ca1d67f1f703cd4e27a2.jpg',
#    'medium_image_url': 'https://bilder.hemnet.se/images/itemgallery_M/54/63/5463061f2f13ca1d67f1f703cd4e27a2.jpg',
#    'url': 'https://obos.se/hitta-bostad/sok-bostad/stockholm/stockholm/stadsljus/?utm_source=hemnet.se&utm_medium=referral&utm_campaign=stadsljus&utm_content=kommandenyproduktion',
#    'iconName': 'bostadsratt',
#    'occupation_date': '',
#    'area': 'Norra Djurgårdsstaden - Gärdet - Hjorthagen - Norra Djurgården',
#    'broker_logo_url': 'https://bilder.hemnet.se/images/broker_logo_1/bf/8b/bf8bf78f332488b3d4780e860397e4f5.png'}],
#  'status': 'for_sale',
#  'search_key': '91d4716f82833881428eaf46da90871b616396b3',
#  'locations': [473397],
#  'assets_prefix': '',
#  'tileserver_host': 'https://tiles.hemnet.se',
#  'map_url': 'https://maps.googleapis.com/maps/api/js?key=AIzaSyAvR8lQbyQytYdggFUVGZekvRFX2fJGGZ0&language=sv&libraries=geometry%2Cplaces&map_ids=f2115f301367545e&region=SE&v=weekly'}

# %%
json_data['search_key']
# Out:
# '91d4716f82833881428eaf46da90871b616396b3'

# %%
url = "https://www.hemnet.se/bostader/search/"+json_data["search_key"]

params= {}
payload={}

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.request(
    "GET",
    url,
    headers=headers,
    data=payload,
    params=params
)

#Hemnet.server.data = {"csrf":{"value":"VOmGRv8XrDstcqwUCZyqjXsVEudWhWcqKr7EafIOH+nsMGU3uERjsiXVGsborb/Phzfr9zcH7lwBkcvEjBm3wQ==","name":"authenticity_token"},"environment":"prod","refreshPath":"/open-api/server-data.json","sentryDSN":"https://d413eda448c64289bd3315951e24b44f@sentry.io/276700","search":{"municipalitiesPath":"/locations/municipalities","newSessionPath":"/mitt_hemnet/session/logga_in"}};

# %%
response.url
# Out:
# 'https://www.hemnet.se/bostader/search/91d4716f82833881428eaf46da90871b616396b3'

# %%
r_json = response.json()
#r_properties = r_json["properties"]
r_json
# Out:
# {'search_bounds': {'southwest': {'lat': 59.34356631535739,
#    'long': 18.03639028260046},
#   'northeast': {'lat': 59.37549682636011, 'long': 18.10699508748713}},
#  'properties': [{'id': 19303181,
#    'coordinate': [59.3718071, 18.0525875],
#    'address': 'Torphagsvägen 8',
#    'location_name': 'Stockholms kommun',
#    'typeSummary': 'Bostadsrättslägenhet',
#    'iconName': 'bostadsratt',
#    'project': False,
#    'new_construction': False,
#    'ongoing_bidding': False,
#    'foreclosure': False,
#    'upcoming': False,
#    'price': '2\xa0995\xa0000\xa0kr',
#    'price_per_area': '59\xa0900\xa0kr/m²',
#    'has_price_change': False,
#    'rooms': '2 rum',
#    'fee': '2\xa0381\xa0kr/mån',
#    'age_string': '<span>8</span> dagar',
#    'age': 8,
#    'deactivated_before_open_house': False,
#    'living_space': {'table': {'living_area': '50 m²',
#      'supplemental_area': None}},
#    'land_area': None,
#    'small_image_url': 'https://bilder.hemnet.se/images/itemgallery_S/8d/c7/8dc7d020f2111a8308d36682c9ba8079.jpg',
#    'medium_image_url': 'https://bilder.hemnet.se/images/itemgallery_M/8d/c7/8dc7d020f2111a8308d36682c9ba8079.jpg',
#    'url': 'https://www.hemnet.se/bostad/lagenhet-2rum-ekhagen-stockholms-kommun-torphagsvagen-8-19303181',
#    'labels': [{'category': 'feature',
#      'identifier': 'elevator',
#      'text': 'Hiss',
#      'priority': 18}],
#    'state_labels': [],
#    'user_saved': False,
#    'save_button_label': 'Spara',
#    'broker_logo_url': 'https://bilder.hemnet.se/images/broker_logo_2/8c/23/8c239b600e72beaa3a82d1778b7217cf.png',
#    'broker_agency_name': 'Alicia Edelman Fastighetsmäkleri',
#    'locations_string': 'Ekhagen, Stockholms kommun',
#    'should_display_showings': False,
#    'should_highlight_showings': False,
#    'trackingData': {'listingId': '19303181',
#     'listingType': 'common_listing',
#     'listingPackageType': 'basic',
#     'listingState': 'active',
#     'listingStatus': 'for_sale'}},
#   {'id': 19237096,
#    'coordinate': [59.37097, 18.0585651],
#    'address': 'Docentbacken 3, 5tr',
#    'location_name': 'Stockholms kommun',
#    'typeSummary': 'Bostadsrättslägenhet',
#    'iconName': 'bostadsratt',
#    'project': False,
#    'new_construction': False,
#    'ongoing_bidding': False,
#    'foreclosure': False,
#    'upcoming': False,
#    'price': '6\xa0195\xa0000\xa0kr',
#    'price_per_area': '64\xa0064\xa0kr/m²',
#    'has_price_change': False,
#    'rooms': '3 rum',
#    'fee': '4\xa0632\xa0kr/mån',
#    'age_string': '<span>25</span> dagar',
#    'age': 25,
#    'deactivated_before_open_house': False,
#    'living_space': {'table': {'living_area': '96,7 m²',
#      'supplemental_area': None}},
#    'land_area': None,
#    'small_image_url': 'https://bilder.hemnet.se/images/itemgallery_S/0b/18/0b18f5fc1e5cad71794d8219000d1d91.jpg',
#    'medium_image_url': 'https://bilder.hemnet.se/images/itemgallery_M/0b/18/0b18f5fc1e5cad71794d8219000d1d91.jpg',
#    'url': 'https://www.hemnet.se/bostad/lagenhet-3rum-ekhagen-stockholms-kommun-docentbacken-3,-5tr-19237096',
#    'labels': [{'category': 'product',
#      'identifier': 'plus',
#      'text': 'Plus',
#      'priority': 9},
#     {'category': 'feature',
#      'identifier': 'balcony',
#      'text': 'Balkong',
#      'priority': 16},
#     {'category': 'feature',
#      'identifier': 'elevator',
#      'text': 'Hiss',
#      'priority': 18}],
#    'state_labels': [],
#    'user_saved': False,
#    'save_button_label': 'Spara',
#    'broker_logo_url': 'https://bilder.hemnet.se/images/broker_logo_2/8f/31/8f3172c1ca67a8c33599b2e1544b4736.png',
#    'broker_agency_name': 'Länsförsäkringar Fastighetsförmedling Stockholm - Östermalm',
#    'locations_string': 'Ekhagen, Stockholms kommun',
#    'should_display_showings': False,
#    'should_highlight_showings': False,
#    'trackingData': {'listingId': '19237096',
#     'listingType': 'common_listing',
#     'listingPackageType': 'plus',
#     'listingState': 'active',
#     'listingStatus': 'for_sale'}},
#   {'id': 19158696,
#    'coordinate': [59.3467369, 18.071619],
#    'address': 'Drottning kristinas väg 11',
#    'location_name': 'Stockholms kommun',
#    'typeSummary': 'Bostadsrättslägenhet',
#    'iconName': 'bostadsratt',
#    'project': False,
#    'new_construction': False,
#    'ongoing_bidding': False,
#    'foreclosure': False,
#    'upcoming': False,
#    'price': '2\xa0800\xa0000\xa0kr',
#    'price_per_area': '80\xa0000\xa0kr/m²',
#    'has_price_change': True,
#    'rooms': '1 rum',
#    'fee': '1\xa0378\xa0kr/mån',
#    'age_string': '<span>43</span> dagar',
#    'age': 43,
#    'deactivated_before_open_house': False,
#    'living_space': {'table': {'living_area': '35 m²',
#      'supplemental_area': None}},
#    'land_area': None,
#    'small_image_url': 'https://bilder.hemnet.se/images/itemgallery_S/70/97/7097b02ef99fd29877cf919252a8bad0.jpg',
#    'medium_image_url': 'https://bilder.hemnet.se/images/itemgallery_M/70/97/7097b02ef99fd29877cf919252a8bad0.jpg',
#    'url': 'https://www.hemnet.se/bostad/lagenhet-1rum-ostermalm-stockholms-kommun-drottning-kristinas-vag-11-19158696',
#    'labels': [{'category': 'product',
#      'identifier': 'premium',
#      'text': 'Premium',
#      'priority': 10},
#     {'category': 'feature',
#      'identifier': 'elevator',
#      'text': 'Hiss',
#      'priority': 18}],
#    'state_labels': [],
#    'user_saved': False,
#    'save_button_label': 'Spara',
#    'broker_logo_url': 'https://bilder.hemnet.se/images/broker_logo_2/6d/b7/6db7ae1ac6c88bf6ac19132d9c93fc93.png',
#    'broker_agency_name': 'Erik Olsson Fastighetsförmedling',
#    'locations_string': 'Östermalm, Stockholms kommun',
#    'should_display_showings': False,
#    'should_highlight_showings': False,
#    'trackingData': {'listingId': '19158696',
#     'listingType': 'common_listing',
#     'listingPackageType': 'premium',
#     'listingState': 'active',
#     'listingStatus': 'for_sale'},
#    'price_change': 12},
#   {'id': 19040044,
#    'coordinate': [59.3488922, 18.0654316],
#    'address': 'Körsbärsvägen 6B',
#    'location_name': 'Stockholms kommun',
#    'typeSummary': 'Bostadsrättslägenhet',
#    'iconName': 'bostadsratt',
#    'project': False,
#    'new_construction': False,
#    'ongoing_bidding': False,
#    'foreclosure': False,
#    'upcoming': False,
#    'price': '3\xa0095\xa0000\xa0kr',
#    'price_per_area': '154\xa0750\xa0kr/m²',
#    'has_price_change': True,
#    'rooms': '2 rum',
#    'fee': '1\xa0903\xa0kr/mån',
#    'age_string': '<span>70</span> dagar',
#    'age': 70,
#    'deactivated_before_open_house': False,
#    'living_space': {'table': {'living_area': '20',
#      'supplemental_area': '11 m²'}},
#    'land_area': None,
#    'small_image_url': 'https://bilder.hemnet.se/images/itemgallery_S/40/c2/40c2d017292ddcad0f2bb74ffbddc9b0.jpg',
#    'medium_image_url': 'https://bilder.hemnet.se/images/itemgallery_M/40/c2/40c2d017292ddcad0f2bb74ffbddc9b0.jpg',
#    'url': 'https://www.hemnet.se/bostad/lagenhet-2rum-stockholms-kommun-korsbarsvagen-6b-19040044',
#    'labels': [{'category': 'product',
#      'identifier': 'plus',
#      'text': 'Plus',
#      'priority': 9}],
#    'state_labels': [],
#    'user_saved': False,
#    'save_button_label': 'Spara',
#    'broker_logo_url': 'https://bilder.hemnet.se/images/broker_logo_2/39/89/39890ee942aadf65e5fe5a0d3b4a2d7a.jpg',
#    'broker_agency_name': 'Unik Fastighetsförmedling AB',
#    'locations_string': 'STOCKHOLM, Stockholms kommun',
#    'should_display_showings': False,
#    'should_highlight_showings': False,
#    'trackingData': {'listingId': '19040044',
#     'listingType': 'common_listing',
#     'listingPackageType': 'plus',
#     'listingState': 'active',
#     'listingStatus': 'for_sale'},
#    'price_change': 7},
#   {'id': 18995294,
#    'coordinate': [59.35124339999999, 18.0632962],
#    'address': 'Ruddammsvägen 21, 2tr',
#    'location_name': 'Stockholms kommun',
#    'typeSummary': 'Bostadsrättslägenhet',
#    'iconName': 'bostadsratt',
#    'project': False,
#    'new_construction': False,
#    'ongoing_bidding': False,
#    'foreclosure': False,
#    'upcoming': False,
#    'price': '4\xa0500\xa0000\xa0kr',
#    'price_per_area': '65\xa0693\xa0kr/m²',
#    'has_price_change': True,
#    'rooms': '2 rum',
#    'fee': '3\xa0563\xa0kr/mån',
#    'age_string': '<span>83</span> dagar',
#    'age': 83,
#    'deactivated_before_open_house': False,
#    'living_space': {'table': {'living_area': '68,5 m²',
#      'supplemental_area': None}},
#    'land_area': None,
#    'small_image_url': 'https://bilder.hemnet.se/images/itemgallery_S/6a/d8/6ad848bb25d6a01c780d8f76d06b3877.jpg',
#    'medium_image_url': 'https://bilder.hemnet.se/images/itemgallery_M/6a/d8/6ad848bb25d6a01c780d8f76d06b3877.jpg',
#    'url': 'https://www.hemnet.se/bostad/lagenhet-2rum-ruddammen-ostermalm-stockholms-kommun-ruddammsvagen-21,-2tr-18995294',
#    'labels': [{'category': 'product',
#      'identifier': 'premium',
#      'text': 'Premium',
#      'priority': 10},
#     {'category': 'feature',
#      'identifier': 'balcony',
#      'text': 'Balkong',
#      'priority': 16},
#     {'category': 'feature',
#      'identifier': 'elevator',
#      'text': 'Hiss',
#      'priority': 18}],
#    'state_labels': [],
#    'user_saved': False,
#    'save_button_label': 'Spara',
#    'broker_logo_url': 'https://bilder.hemnet.se/images/broker_logo_2/63/7c/637c17c40a250ef71084ac34e860d757.jpg',
#    'broker_agency_name': 'SkandiaMäklarna Stockholm Östermalm',
#    'locations_string': 'Ruddammen / Östermalm, Stockholms kommun',
#    'should_display_showings': False,
#    'should_highlight_showings': False,
#    'trackingData': {'listingId': '18995294',
#     'listingType': 'common_listing',
#     'listingPackageType': 'premium',
#     'listingState': 'active',
#     'listingStatus': 'for_sale'},
#    'price_change': -10},
#   {'id': 18610356,
#    'coordinate': [59.35137, 18.0637226],
#    'address': 'Ruddammsvägen 23',
#    'location_name': 'Stockholms kommun',
#    'typeSummary': 'Bostadsrättslägenhet',
#    'iconName': 'bostadsratt',
#    'project': False,
#    'new_construction': False,
#    'ongoing_bidding': False,
#    'foreclosure': False,
#    'upcoming': False,
#    'price': '4\xa0495\xa0000\xa0kr',
#    'price_per_area': '69\xa0690\xa0kr/m²',
#    'has_price_change': False,
#    'rooms': '2 rum',
#    'fee': '3\xa0464\xa0kr/mån',
#    'age_string': '<span>105</span> dagar',
#    'age': 105,
#    'deactivated_before_open_house': False,
#    'living_space': {'table': {'living_area': '64,5 m²',
#      'supplemental_area': None}},
#    'land_area': None,
#    'small_image_url': 'https://bilder.hemnet.se/images/itemgallery_S/67/c4/67c487ad0d579c2a3cb2558c3a3c7403.jpg',
#    'medium_image_url': 'https://bilder.hemnet.se/images/itemgallery_M/67/c4/67c487ad0d579c2a3cb2558c3a3c7403.jpg',
#    'url': 'https://www.hemnet.se/bostad/lagenhet-2rum-ruddammen-stockholms-kommun-ruddammsvagen-23-18610356',
#    'labels': [{'category': 'product',
#      'identifier': 'plus',
#      'text': 'Plus',
#      'priority': 9},
#     {'category': 'feature',
#      'identifier': 'balcony',
#      'text': 'Balkong',
#      'priority': 16},
#     {'category': 'feature',
#      'identifier': 'elevator',
#      'text': 'Hiss',
#      'priority': 18}],
#    'state_labels': [],
#    'user_saved': False,
#    'save_button_label': 'Spara',
#    'broker_logo_url': 'https://bilder.hemnet.se/images/broker_logo_2/8f/31/8f3172c1ca67a8c33599b2e1544b4736.png',
#    'broker_agency_name': 'Länsförsäkringar Fastighetsförmedling Stockholm - Östermalm',
#    'locations_string': 'Ruddammen, Stockholms kommun',
#    'should_display_showings': False,
#    'should_highlight_showings': False,
#    'trackingData': {'listingId': '18610356',
#     'listingType': 'common_listing',
#     'listingPackageType': 'plus',
#     'listingState': 'active',
#     'listingStatus': 'for_sale'}},
#   {'id': 18890675,
#    'coordinate': [59.3720245, 18.0539627],
#    'address': 'Torphagsvägen 16',
#    'location_name': 'Stockholms kommun',
#    'typeSummary': 'Bostadsrättslägenhet',
#    'iconName': 'bostadsratt',
#    'project': False,
#    'new_construction': False,
#    'ongoing_bidding': False,
#    'foreclosure': False,
#    'upcoming': False,
#    'price': '2\xa0295\xa0000\xa0kr',
#    'price_per_area': '81\xa0964\xa0kr/m²',
#    'has_price_change': False,
#    'rooms': '1 rum',
#    'fee': '1\xa0818\xa0kr/mån',
#    'age_string': '<span>123</span> dagar',
#    'age': 123,
#    'deactivated_before_open_house': False,
#    'living_space': {'table': {'living_area': '28 m²',
#      'supplemental_area': None}},
#    'land_area': None,
#    'small_image_url': 'https://bilder.hemnet.se/images/itemgallery_S/e4/bd/e4bd497dc263b3880dfffaf40bc58b54.jpg',
#    'medium_image_url': 'https://bilder.hemnet.se/images/itemgallery_M/e4/bd/e4bd497dc263b3880dfffaf40bc58b54.jpg',
#    'url': 'https://www.hemnet.se/bostad/lagenhet-1rum-stockholms-kommun-torphagsvagen-16-18890675',
#    'labels': [{'category': 'feature',
#      'identifier': 'balcony',
#      'text': 'Balkong',
#      'priority': 16}],
#    'state_labels': [],
#    'user_saved': False,
#    'save_button_label': 'Spara',
#    'broker_logo_url': 'https://bilder.hemnet.se/images/broker_logo_2/29/ef/29ef6ea0936106a0033c5f69a2feda85.png',
#    'broker_agency_name': 'Historiska Hem',
#    'locations_string': 'STOCKHOLM, Stockholms kommun',
#    'should_display_showings': False,
#    'should_highlight_showings': False,
#    'trackingData': {'listingId': '18890675',
#     'listingType': 'common_listing',
#     'listingPackageType': 'basic',
#     'listingState': 'active',
#     'listingStatus': 'for_sale'}}]}

# %%
# Store all the listings in that area as a dataframe
df = pd.json_normalize(
    r_properties,
    max_level=1
)

print(f"{area}:\t\t {df.shape}")

# Enrich the df with info about internal area naming and date  
df["area"] = area
df["date"] = dateoftoday

# Update the listings_count
listings_count += df.shape[0]

#Update the area_info dictionary
area_info[area]["listings"] = df.shape[0]

# Save the dataframe inside directory
df.to_parquet(f"{directory_path}{area}.parquet.gzip", compression="gzip")
    
print(f"\n{listings_count} listings in the areas of interest today!")

area_info["total_listings"] = listings_count

with open(f"{directory_path}area_info{dateoftoday}.yml", "w") as outfile:
    yaml.dump(area_info, outfile, default_flow_style=False)
with open(f"{directory_path}area_info{dateoftoday}.txt", "w") as convert_file:
    convert_file.write(json.dumps(area_info))
# Out:
# gamla_stan:		 (7, 39)
#
# 7 listings in the areas of interest today!
