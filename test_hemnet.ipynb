# %%
import pandas as pd
from lxml import etree
import requests

# %%
url = "https://www.hemnet.se/bostader/search/4ecea389b4a54b37499b7dbe2ae07e6c72624b37"

payload={}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'
}

response = requests.request("GET", url, headers=headers, data=payload)

#print(response.text)

# %%
r_json = response.json()
r_prop = r_json['properties']
#r_prop

# %%
df=pd.json_normalize(r_prop, max_level=0)
df
# Out:
#           id                                coordinate  \
# 0   19204395                    [59.3498077, 17.99325]
# 1   19197055  [59.351894377382045, 18.004863691857967]
# 2   19219416                  [59.3452835, 17.9993477]
# 3   18743994     [59.3498668998762, 17.98517043347394]
# 4   19198756                      [59.35206, 18.00463]
# 5   19189918    [59.34957638374249, 17.99313340977581]
# 6   19190060                   [59.3495733, 17.995246]
# 7   19190220                  [59.3533249, 17.9959946]
# 8   19131455                     [59.34989, 17.985893]
# 9   19186106                    [59.34998, 17.9940586]
# 10  19147038                   [59.353878, 17.9832649]
# 11  19176057                  [59.3498713, 17.9851696]
# 12  19171898                      [59.34929, 17.98037]
# 13  19171795                  [59.3486443, 17.9874783]
# 14  19165936                  [59.3491974, 17.9805241]
# 15  19157622                  [59.3517952, 18.0091953]
# 16  19158480                  [59.3545265, 18.0000038]
# 17  19103477                   [59.3481422, 17.998632]
# 18  19124215                  [59.3531605, 18.0038794]
# 19  18305727                  [59.3486366, 17.9812679]
# 20  19156277                     [59.34535, 18.001667]
# 21  18568977                     [59.3477, 17.9922829]
# 22  19076600                  [59.3515968, 18.0093384]
# 23  19127258                  [59.3455124, 17.9999428]
# 24  19126820                  [59.3528862, 17.9798183]
# 25  19125454                  [59.3459244, 18.0033722]
# 26  19123956                    [59.3482475, 17.99857]
# 27  19073395                      [59.34604, 17.99678]
# 28  18565055                      [59.35204, 18.00686]
# 29  18305607                      [59.34723, 17.99263]
# 30  19097123                     [59.34845, 17.982151]
# 31  19091275                  [59.3520432, 18.0034275]
# 32  19035676                  [59.3484268, 17.9966526]
# 33  19039435                    [59.351376, 18.000935]
# 34  19062176                  [59.3533325, 17.9959965]
# 35  19045035                      [59.3473854, 18.003]
# 36  19037557                  [59.3476334, 17.9867325]
# 37  18709636                  [59.3526268, 17.9964581]
# 38  19022498  [59.354601904087424, 17.994596855138543]
# 39  19019097                  [59.3515663, 18.0025654]
# 40  18971440                   [59.349472, 17.9872856]
# 41  18739141                     [59.3525, 18.0026016]
# 42  19017823                    [59.35122, 17.9998055]
# 43  18540597                   [59.3530215, 18.003926]
# 44  18879156                    [59.35262, 18.0017433]
# 45  18673437                  [59.3486748, 17.9813118]
# 46  18865498                    [59.35114, 17.9844666]
# 47  18745686                  [59.3524088, 18.0057047]
# 48  18828868                    [59.3512726, 17.98364]
# 49  18873377                    [59.35128, 18.0036545]
# 50  18811497                      [59.34743, 17.99581]
# 51  18967020                  [59.3522949, 17.9911919]
# 52  18776896                      [59.35138, 18.00093]
# 53  18940260                  [59.3482857, 17.9881649]
# 54  18521397                  [59.3522949, 17.9960957]
# 55  18776655                  [59.3522873, 18.0055256]
# 56  18865855                   [59.3542862, 18.000412]
# 57  16919843                   [59.351944, 18.0082626]
#
#                                 address location_name           typeSummary  \
# 0            Krysshammarvägen 30, vån 4  Solna kommun  Bostadsrättslägenhet
# 1                         Armégatan 11b  Solna kommun  Bostadsrättslägenhet
# 2                  Johan Enbergs väg 64  Solna kommun  Bostadsrättslägenhet
# 3                         Storgatan 72A  Solna kommun  Bostadsrättslägenhet
# 4                         Armégatan 11A  Solna kommun  Bostadsrättslägenhet
# 5             Krysshammarvägen 32, 5tr!  Solna kommun  Bostadsrättslägenhet
# 6                    Krysshammarvägen 4  Solna kommun  Bostadsrättslägenhet
# 7                        Polhemsgatan 4  Solna kommun  Bostadsrättslägenhet
# 8                         Storgatan 70B  Solna kommun  Bostadsrättslägenhet
# 9                   Krysshammarvägen 22  Solna kommun  Bostadsrättslägenhet
# 10          Göran Perssons Väg 29, 2 tr  Solna kommun  Bostadsrättslägenhet
# 11                        Storgatan 72A  Solna kommun  Bostadsrättslägenhet
# 12                     Jungfrudansen 52  Solna kommun  Bostadsrättslägenhet
# 13                      Jungfrudansen 7  Solna kommun  Bostadsrättslägenhet
# 14                     Jungfrudansen 50  Solna kommun  Bostadsrättslägenhet
# 15                 Arvid Tydéns allé 26  Solna kommun  Bostadsrättslägenhet
# 16                          Bangatan 1D  Solna kommun  Bostadsrättslägenhet
# 17      Armégatan 25, Högt upp i huset!  Solna kommun  Bostadsrättslägenhet
# 18      Armégatan 3,  Högt upp i huset!  Solna kommun  Bostadsrättslägenhet
# 19              Jungfrudansen 42, vån 2  Solna kommun  Bostadsrättslägenhet
# 20           Johan Enbergs väg 15, 1 tr  Solna kommun  Bostadsrättslägenhet
# 21         Kristinelundsvägen 34, vån 1  Solna kommun  Bostadsrättslägenhet
# 22        Arvid Tydéns Allé 28, vån 4/4  Solna kommun  Bostadsrättslägenhet
# 23                Johan Enbergs väg 54B  Solna kommun  Bostadsrättslägenhet
# 24                    Jonstorpsvägen 28  Solna kommun  Bostadsrättslägenhet
# 25           Johan Enbergs väg 9, vån 7  Solna kommun  Bostadsrättslägenhet
# 26                  Armégatan 25, vån 6  Solna kommun  Bostadsrättslägenhet
# 27                        Wiboms väg 12  Solna kommun  Bostadsrättslägenhet
# 28                        Diktarvägen 8  Solna kommun  Bostadsrättslägenhet
# 29                Kristinelundsvägen 46  Solna kommun  Bostadsrättslägenhet
# 30               Jungfrudansen 40, 2 tr  Solna kommun  Bostadsrättslägenhet
# 31                     Infanterigatan 5  Solna kommun  Bostadsrättslägenhet
# 32                   Wiboms Väg 2, 6 tr  Solna kommun  Bostadsrättslägenhet
# 33                    Infanterigatan 17  Solna kommun  Bostadsrättslägenhet
# 34                 Polhemsgatan 4, 3 tr  Solna kommun  Bostadsrättslägenhet
# 35          Johan Enbergs väg 28, vån 5  Solna kommun  Bostadsrättslägenhet
# 36               Jungfrudansen 12, 2 tr  Solna kommun  Bostadsrättslägenhet
# 37               Huvudstagatan 14A, 3tr  Solna kommun  Bostadsrättslägenhet
# 38                 Oskarsrogatan 5, 7tr  Solna kommun  Bostadsrättslägenhet
# 39                     Infanterigatan 9  Solna kommun  Bostadsrättslägenhet
# 40                        Storgatan 62C  Solna kommun  Bostadsrättslägenhet
# 41  Kapellgatan 18 / Ingentingsgatan 14  Solna kommun  Bostadsrättslägenhet
# 42                    Infanterigatan 25  Solna kommun  Bostadsrättslägenhet
# 43      Armégatan 5, HÖGST UPP I HUSET!  Solna kommun  Bostadsrättslägenhet
# 44                 Kapellgatan 20, 2 tr  Solna kommun  Bostadsrättslägenhet
# 45                     Jungfrudansen 44  Solna kommun  Bostadsrättslägenhet
# 46                           Bygatan 25  Solna kommun  Bostadsrättslägenhet
# 47                Trubadurvägen 3, 2 tr  Solna kommun  Bostadsrättslägenhet
# 48                     Bygatan 21, 2 tr  Solna kommun  Bostadsrättslägenhet
# 49                 Armégatan 28, vån 3!  Solna kommun  Bostadsrättslägenhet
# 50                  Wiboms Väg 6, 7 tr   Solna kommun  Bostadsrättslägenhet
# 51                 Släggbacken 7, vån 6  Solna kommun  Bostadsrättslägenhet
# 52                    Infanterigatan 17  Solna kommun  Bostadsrättslägenhet
# 53                     Jungfrudansen 11  Solna kommun  Bostadsrättslägenhet
# 54              Karolinagatan 1, vån 2!  Solna kommun  Bostadsrättslägenhet
# 55                      Trubadurvägen 3  Solna kommun  Bostadsrättslägenhet
# 56                     Järnvägsgatan 2E  Solna kommun  Bostadsrättslägenhet
# 57     Arvid Tydéns allé 18, vån 6 av 6  Solna kommun  Bostadsrättslägenhet
#
#        iconName  project  new_construction  ongoing_bidding  foreclosure  ...  \
# 0   bostadsratt    False             False            False        False  ...
# 1   bostadsratt    False             False            False        False  ...
# 2   bostadsratt    False             False            False        False  ...
# 3   bostadsratt    False             False            False        False  ...
# 4   bostadsratt    False             False            False        False  ...
# 5   bostadsratt    False             False            False        False  ...
# 6   bostadsratt    False             False            False        False  ...
# 7   bostadsratt    False             False            False        False  ...
# 8   bostadsratt    False             False            False        False  ...
# 9   bostadsratt    False             False            False        False  ...
# 10  bostadsratt    False             False            False        False  ...
# 11  bostadsratt    False             False            False        False  ...
# 12  bostadsratt    False             False             True        False  ...
# 13  bostadsratt    False             False            False        False  ...
# 14  bostadsratt    False             False            False        False  ...
# 15  bostadsratt    False             False             True        False  ...
# 16  bostadsratt    False             False            False        False  ...
# 17  bostadsratt    False             False             True        False  ...
# 18  bostadsratt    False             False             True        False  ...
# 19  bostadsratt    False             False            False        False  ...
# 20  bostadsratt    False             False            False        False  ...
# 21  bostadsratt    False             False             True        False  ...
# 22  bostadsratt    False             False            False        False  ...
# 23  bostadsratt    False             False             True        False  ...
# 24  bostadsratt    False             False             True        False  ...
# 25  bostadsratt    False             False             True        False  ...
# 26  bostadsratt    False             False            False        False  ...
# 27  bostadsratt    False             False             True        False  ...
# 28  bostadsratt    False             False             True        False  ...
# 29  bostadsratt    False             False            False        False  ...
# 30  bostadsratt    False             False            False        False  ...
# 31  bostadsratt    False             False             True        False  ...
# 32  bostadsratt    False             False            False        False  ...
# 33  bostadsratt    False             False             True        False  ...
# 34  bostadsratt    False             False            False        False  ...
# 35  bostadsratt    False             False            False        False  ...
# 36  bostadsratt    False             False            False        False  ...
# 37  bostadsratt    False             False            False        False  ...
# 38  bostadsratt    False             False            False        False  ...
# 39  bostadsratt    False             False            False        False  ...
# 40  bostadsratt    False             False            False        False  ...
# 41  bostadsratt    False             False            False        False  ...
# 42  bostadsratt    False             False            False        False  ...
# 43  bostadsratt    False             False             True        False  ...
# 44  bostadsratt    False             False            False        False  ...
# 45  bostadsratt    False             False            False        False  ...
# 46  bostadsratt    False             False             True        False  ...
# 47  bostadsratt    False             False             True        False  ...
# 48  bostadsratt    False             False            False        False  ...
# 49  bostadsratt    False             False            False        False  ...
# 50  bostadsratt    False             False             True        False  ...
# 51  bostadsratt    False             False            False        False  ...
# 52  bostadsratt    False             False             True        False  ...
# 53  bostadsratt    False             False             True        False  ...
# 54  bostadsratt    False             False            False        False  ...
# 55  bostadsratt    False             False             True        False  ...
# 56  bostadsratt    False             False            False        False  ...
# 57  bostadsratt    False             False            False        False  ...
#
#                                       broker_logo_url  \
# 0   https://bilder.hemnet.se/images/broker_logo_2/...
# 1   https://bilder.hemnet.se/images/broker_logo_2/...
# 2   https://bilder.hemnet.se/images/broker_logo_2/...
# 3   https://bilder.hemnet.se/images/broker_logo_2/...
# 4   https://bilder.hemnet.se/images/broker_logo_2/...
# 5   https://bilder.hemnet.se/images/broker_logo_2/...
# 6   https://bilder.hemnet.se/images/broker_logo_2/...
# 7   https://bilder.hemnet.se/images/broker_logo_2/...
# 8   https://bilder.hemnet.se/images/broker_logo_2/...
# 9   https://bilder.hemnet.se/images/broker_logo_2/...
# 10  https://bilder.hemnet.se/images/broker_logo_2/...
# 11  https://bilder.hemnet.se/images/broker_logo_2/...
# 12  https://bilder.hemnet.se/images/broker_logo_2/...
# 13  https://bilder.hemnet.se/images/broker_logo_2/...
# 14  https://bilder.hemnet.se/images/broker_logo_2/...
# 15  https://bilder.hemnet.se/images/broker_logo_2/...
# 16  https://bilder.hemnet.se/images/broker_logo_2/...
# 17  https://bilder.hemnet.se/images/broker_logo_2/...
# 18  https://bilder.hemnet.se/images/broker_logo_2/...
# 19  https://bilder.hemnet.se/images/broker_logo_2/...
# 20  https://bilder.hemnet.se/images/broker_logo_2/...
# 21  https://bilder.hemnet.se/images/broker_logo_2/...
# 22  https://bilder.hemnet.se/images/broker_logo_2/...
# 23  https://bilder.hemnet.se/images/broker_logo_2/...
# 24  https://bilder.hemnet.se/images/broker_logo_2/...
# 25  https://bilder.hemnet.se/images/broker_logo_2/...
# 26  https://bilder.hemnet.se/images/broker_logo_2/...
# 27  https://bilder.hemnet.se/images/broker_logo_2/...
# 28  https://bilder.hemnet.se/images/broker_logo_2/...
# 29  https://bilder.hemnet.se/images/broker_logo_2/...
# 30  https://bilder.hemnet.se/images/broker_logo_2/...
# 31  https://bilder.hemnet.se/images/broker_logo_2/...
# 32  https://bilder.hemnet.se/images/broker_logo_2/...
# 33  https://bilder.hemnet.se/images/broker_logo_2/...
# 34  https://bilder.hemnet.se/images/broker_logo_2/...
# 35  https://bilder.hemnet.se/images/broker_logo_2/...
# 36  https://bilder.hemnet.se/images/broker_logo_2/...
# 37  https://bilder.hemnet.se/images/broker_logo_2/...
# 38  https://bilder.hemnet.se/images/broker_logo_2/...
# 39  https://bilder.hemnet.se/images/broker_logo_2/...
# 40  https://bilder.hemnet.se/images/broker_logo_2/...
# 41  https://bilder.hemnet.se/images/broker_logo_2/...
# 42  https://bilder.hemnet.se/images/broker_logo_2/...
# 43  https://bilder.hemnet.se/images/broker_logo_2/...
# 44  https://bilder.hemnet.se/images/broker_logo_2/...
# 45  https://bilder.hemnet.se/images/broker_logo_2/...
# 46  https://bilder.hemnet.se/images/broker_logo_2/...
# 47  https://bilder.hemnet.se/images/broker_logo_2/...
# 48  https://bilder.hemnet.se/images/broker_logo_2/...
# 49  https://bilder.hemnet.se/images/broker_logo_2/...
# 50  https://bilder.hemnet.se/images/broker_logo_2/...
# 51  https://bilder.hemnet.se/images/broker_logo_2/...
# 52  https://bilder.hemnet.se/images/broker_logo_2/...
# 53  https://bilder.hemnet.se/images/broker_logo_2/...
# 54  https://bilder.hemnet.se/images/broker_logo_2/...
# 55  https://bilder.hemnet.se/images/broker_logo_2/...
# 56  https://bilder.hemnet.se/images/broker_logo_2/...
# 57  https://bilder.hemnet.se/images/broker_logo_2/...
#
#                              broker_agency_name  \
# 0   Länsförsäkringar Fastighetsförmedling Solna
# 1                                 Urban by ESNY
# 2                                         Notar
# 3                                     SthlmFast
# 4                                    MOHV Solna
# 5                                BOSTHLM Älvsjö
# 6                             Mäklarhuset Solna
# 7                           HusmanHagberg Solna
# 8                         Fastighetsbyrån Solna
# 9   Länsförsäkringar Fastighetsförmedling Solna
# 10  Länsförsäkringar Fastighetsförmedling Solna
# 11                        SkandiaMäklarna Solna
# 12            Svensk Fastighetsförmedling Solna
# 13                                        Notar
# 14                                        Notar
# 15                                        Notar
# 16                Simon Crest Fastighetsmäkleri
# 17                        SkandiaMäklarna Solna
# 18                        SkandiaMäklarna Solna
# 19  Länsförsäkringar Fastighetsförmedling Solna
# 20  Länsförsäkringar Fastighetsförmedling Solna
# 21  Länsförsäkringar Fastighetsförmedling Solna
# 22  Länsförsäkringar Fastighetsförmedling Solna
# 23                    Svenska Mäklarhuset Solna
# 24                    Svenska Mäklarhuset Solna
# 25  Länsförsäkringar Fastighetsförmedling Solna
# 26  Länsförsäkringar Fastighetsförmedling Solna
# 27  Länsförsäkringar Fastighetsförmedling Solna
# 28                                   MOHV Solna
# 29                                        Notar
# 30             Erik Olsson Fastighetsförmedling
# 31             Erik Olsson Fastighetsförmedling
# 32                          HusmanHagberg Solna
# 33                        Fastighetsbyrån Solna
# 34  Länsförsäkringar Fastighetsförmedling Solna
# 35                                   MOHV Solna
# 36  Länsförsäkringar Fastighetsförmedling Solna
# 37                                   MOHV Solna
# 38                               BOSTHLM Älvsjö
# 39                                        Notar
# 40                    Svenska Mäklarhuset Solna
# 41  Länsförsäkringar Fastighetsförmedling Solna
# 42                                       Norban
# 43                        SkandiaMäklarna Solna
# 44                          HusmanHagberg Solna
# 45             Erik Olsson Fastighetsförmedling
# 46                                        Notar
# 47                        SkandiaMäklarna Solna
# 48  Länsförsäkringar Fastighetsförmedling Solna
# 49  Länsförsäkringar Fastighetsförmedling Solna
# 50            Svensk Fastighetsförmedling Solna
# 51  Länsförsäkringar Fastighetsförmedling Solna
# 52  Länsförsäkringar Fastighetsförmedling Solna
# 53                                        Notar
# 54  Länsförsäkringar Fastighetsförmedling Solna
# 55  Länsförsäkringar Fastighetsförmedling Solna
# 56                Simon Crest Fastighetsmäkleri
# 57                                   MOHV Solna
#
#                                      locations_string  \
# 0                              Huvudsta, Solna kommun
# 1                                 Solna, Solna kommun
# 2                         Västra Skogen, Solna kommun
# 3                      Huvudsta centrum, Solna kommun
# 4               Västra Skogen/Ingenting, Solna kommun
# 5                      Solna / Huvudsta, Solna kommun
# 6                              Huvudsta, Solna kommun
# 7                        Gamla Huvudsta, Solna kommun
# 8                              Huvudsta, Solna kommun
# 9                              Huvudsta, Solna kommun
# 10                             Huvudsta, Solna kommun
# 11                       Huvudsta/Solna, Solna kommun
# 12  Jungfrudansen, Huvudsta, Västra Skogen, Solna ...
# 13                             Huvudsta, Solna kommun
# 14                             Huvudsta, Solna kommun
# 15                 Huvudsta - Ingenting, Solna kommun
# 16                                Solna, Solna kommun
# 17               Huvudsta/Västra skogen, Solna kommun
# 18                        Västra Skogen, Solna kommun
# 19                             Huvudsta, Solna kommun
# 20                        Västra Skogen, Solna kommun
# 21                             Huvudsta, Solna kommun
# 22                        Västra Skogen, Solna kommun
# 23                        Västra Skogen, Solna kommun
# 24                             Huvudsta, Solna kommun
# 25                        Västra Skogen, Solna kommun
# 26                             Huvudsta, Solna kommun
# 27                             Huvudsta, Solna kommun
# 28              Västra Skogen/Ingenting, Solna kommun
# 29                             Huvudsta, Solna kommun
# 30                        Jungfrudansen, Solna kommun
# 31                             Huvudsta, Solna kommun
# 32                        Västra Skogen, Solna kommun
# 33                        Västra Skogen, Solna kommun
# 34                       Gamla Huvudsta, Solna kommun
# 35                        Västra Skogen, Solna kommun
# 36                             Huvudsta, Solna kommun
# 37                             Huvudsta, Solna kommun
# 38                                Solna, Solna kommun
# 39                             Huvudsta, Solna kommun
# 40                             Huvudsta, Solna kommun
# 41                        Västra Skogen, Solna kommun
# 42                                Solna, Solna kommun
# 43                        Västra Skogen, Solna kommun
# 44                        Västra Skogen, Solna kommun
# 45                                SOLNA, Solna kommun
# 46                             Huvudsta, Solna kommun
# 47                        Västra Skogen, Solna kommun
# 48                             Huvudsta, Solna kommun
# 49                        Västra Skogen, Solna kommun
# 50                             Huvudsta, Solna kommun
# 51                             Huvudsta, Solna kommun
# 52                        Västra Skogen, Solna kommun
# 53                             Huvudsta, Solna kommun
# 54                       Gamla Huvudsta, Solna kommun
# 55                             Huvudsta, Solna kommun
# 56                                Solna, Solna kommun
# 57              Västra Skogen/Ingenting, Solna kommun
#
#     should_display_showings should_highlight_showings  \
# 0                     False                     False
# 1                     False                      True
# 2                     False                     False
# 3                     False                      True
# 4                     False                      True
# 5                     False                      True
# 6                     False                     False
# 7                     False                     False
# 8                     False                      True
# 9                     False                     False
# 10                    False                     False
# 11                    False                     False
# 12                    False                      True
# 13                    False                      True
# 14                    False                     False
# 15                    False                     False
# 16                    False                      True
# 17                    False                      True
# 18                    False                      True
# 19                    False                     False
# 20                    False                      True
# 21                    False                     False
# 22                    False                      True
# 23                    False                     False
# 24                    False                     False
# 25                    False                     False
# 26                    False                     False
# 27                    False                     False
# 28                    False                     False
# 29                    False                      True
# 30                    False                     False
# 31                    False                     False
# 32                    False                     False
# 33                    False                     False
# 34                    False                      True
# 35                    False                     False
# 36                    False                     False
# 37                    False                     False
# 38                    False                     False
# 39                    False                     False
# 40                    False                     False
# 41                    False                     False
# 42                    False                     False
# 43                    False                     False
# 44                    False                     False
# 45                    False                     False
# 46                    False                     False
# 47                    False                      True
# 48                    False                     False
# 49                    False                     False
# 50                    False                     False
# 51                    False                      True
# 52                    False                     False
# 53                    False                     False
# 54                    False                     False
# 55                    False                     False
# 56                    False                     False
# 57                    False                     False
#
#                                          trackingData   broker_name  \
# 0   {'listingId': '19204395', 'listingType': 'comm...           NaN
# 1   {'listingId': '19197055', 'listingType': 'comm...           NaN
# 2   {'listingId': '19219416', 'listingType': 'comm...           NaN
# 3   {'listingId': '18743994', 'listingType': 'comm...           NaN
# 4   {'listingId': '19198756', 'listingType': 'comm...           NaN
# 5   {'listingId': '19189918', 'listingType': 'comm...           NaN
# 6   {'listingId': '19190060', 'listingType': 'comm...           NaN
# 7   {'listingId': '19190220', 'listingType': 'comm...           NaN
# 8   {'listingId': '19131455', 'listingType': 'comm...           NaN
# 9   {'listingId': '19186106', 'listingType': 'comm...  Mike Chammas
# 10  {'listingId': '19147038', 'listingType': 'comm...           NaN
# 11  {'listingId': '19176057', 'listingType': 'comm...           NaN
# 12  {'listingId': '19171898', 'listingType': 'comm...           NaN
# 13  {'listingId': '19171795', 'listingType': 'comm...           NaN
# 14  {'listingId': '19165936', 'listingType': 'comm...           NaN
# 15  {'listingId': '19157622', 'listingType': 'comm...           NaN
# 16  {'listingId': '19158480', 'listingType': 'comm...           NaN
# 17  {'listingId': '19103477', 'listingType': 'comm...           NaN
# 18  {'listingId': '19124215', 'listingType': 'comm...           NaN
# 19  {'listingId': '18305727', 'listingType': 'comm...           NaN
# 20  {'listingId': '19156277', 'listingType': 'comm...           NaN
# 21  {'listingId': '18568977', 'listingType': 'comm...           NaN
# 22  {'listingId': '19076600', 'listingType': 'comm...           NaN
# 23  {'listingId': '19127258', 'listingType': 'comm...           NaN
# 24  {'listingId': '19126820', 'listingType': 'comm...           NaN
# 25  {'listingId': '19125454', 'listingType': 'comm...           NaN
# 26  {'listingId': '19123956', 'listingType': 'comm...           NaN
# 27  {'listingId': '19073395', 'listingType': 'comm...           NaN
# 28  {'listingId': '18565055', 'listingType': 'comm...           NaN
# 29  {'listingId': '18305607', 'listingType': 'comm...           NaN
# 30  {'listingId': '19097123', 'listingType': 'comm...           NaN
# 31  {'listingId': '19091275', 'listingType': 'comm...           NaN
# 32  {'listingId': '19035676', 'listingType': 'comm...           NaN
# 33  {'listingId': '19039435', 'listingType': 'comm...           NaN
# 34  {'listingId': '19062176', 'listingType': 'comm...           NaN
# 35  {'listingId': '19045035', 'listingType': 'comm...           NaN
# 36  {'listingId': '19037557', 'listingType': 'comm...           NaN
# 37  {'listingId': '18709636', 'listingType': 'comm...           NaN
# 38  {'listingId': '19022498', 'listingType': 'comm...           NaN
# 39  {'listingId': '19019097', 'listingType': 'comm...           NaN
# 40  {'listingId': '18971440', 'listingType': 'comm...           NaN
# 41  {'listingId': '18739141', 'listingType': 'comm...           NaN
# 42  {'listingId': '19017823', 'listingType': 'comm...           NaN
# 43  {'listingId': '18540597', 'listingType': 'comm...           NaN
# 44  {'listingId': '18879156', 'listingType': 'comm...           NaN
# 45  {'listingId': '18673437', 'listingType': 'comm...           NaN
# 46  {'listingId': '18865498', 'listingType': 'comm...           NaN
# 47  {'listingId': '18745686', 'listingType': 'comm...           NaN
# 48  {'listingId': '18828868', 'listingType': 'comm...           NaN
# 49  {'listingId': '18873377', 'listingType': 'comm...           NaN
# 50  {'listingId': '18811497', 'listingType': 'comm...           NaN
# 51  {'listingId': '18967020', 'listingType': 'comm...           NaN
# 52  {'listingId': '18776896', 'listingType': 'comm...           NaN
# 53  {'listingId': '18940260', 'listingType': 'comm...           NaN
# 54  {'listingId': '18521397', 'listingType': 'comm...           NaN
# 55  {'listingId': '18776655', 'listingType': 'comm...           NaN
# 56  {'listingId': '18865855', 'listingType': 'comm...           NaN
# 57  {'listingId': '16919843', 'listingType': 'comm...           NaN
#
#      broker_phone              broker_email price_change
# 0             NaN                       NaN          NaN
# 1             NaN                       NaN          NaN
# 2             NaN                       NaN          NaN
# 3             NaN                       NaN          NaN
# 4             NaN                       NaN          NaN
# 5             NaN                       NaN          NaN
# 6             NaN                       NaN          NaN
# 7             NaN                       NaN          NaN
# 8             NaN                       NaN          NaN
# 9   0708-83 83 37  mike.chammas@lansfast.se          NaN
# 10            NaN                       NaN          NaN
# 11            NaN                       NaN          NaN
# 12            NaN                       NaN          NaN
# 13            NaN                       NaN          NaN
# 14            NaN                       NaN          NaN
# 15            NaN                       NaN          NaN
# 16            NaN                       NaN          NaN
# 17            NaN                       NaN          NaN
# 18            NaN                       NaN          NaN
# 19            NaN                       NaN          NaN
# 20            NaN                       NaN          NaN
# 21            NaN                       NaN          NaN
# 22            NaN                       NaN          NaN
# 23            NaN                       NaN          NaN
# 24            NaN                       NaN          NaN
# 25            NaN                       NaN          NaN
# 26            NaN                       NaN          NaN
# 27            NaN                       NaN         14.0
# 28            NaN                       NaN         16.0
# 29            NaN                       NaN        -19.0
# 30            NaN                       NaN          NaN
# 31            NaN                       NaN          NaN
# 32            NaN                       NaN          NaN
# 33            NaN                       NaN         12.0
# 34            NaN                       NaN          NaN
# 35            NaN                       NaN         -8.0
# 36            NaN                       NaN          NaN
# 37            NaN                       NaN          NaN
# 38            NaN                       NaN          NaN
# 39            NaN                       NaN         17.0
# 40            NaN                       NaN        -11.0
# 41            NaN                       NaN          NaN
# 42            NaN                       NaN         13.0
# 43            NaN                       NaN        -18.0
# 44            NaN                       NaN          NaN
# 45            NaN                       NaN          NaN
# 46            NaN                       NaN         13.0
# 47            NaN                       NaN         11.0
# 48            NaN                       NaN          6.0
# 49            NaN                       NaN         10.0
# 50            NaN                       NaN         -6.0
# 51            NaN                       NaN          NaN
# 52            NaN                       NaN          NaN
# 53            NaN                       NaN         15.0
# 54            NaN                       NaN         12.0
# 55            NaN                       NaN          NaN
# 56            NaN                       NaN          NaN
# 57            NaN                       NaN          NaN
#
# [58 rows x 38 columns]

# %%
df['price']
# Out:
# 0     3 495 000 kr
# 1     4 995 000 kr
# 2     6 450 000 kr
# 3     2 390 000 kr
# 4     2 995 000 kr
# 5     4 495 000 kr
# 6     2 395 000 kr
# 7     3 895 000 kr
# 8     2 295 000 kr
# 9     2 095 000 kr
# 10    3 995 000 kr
# 11    4 995 000 kr
# 12    2 795 000 kr
# 13    1 950 000 kr
# 14    3 995 000 kr
# 15    3 595 000 kr
# 16    1 650 000 kr
# 17    4 995 000 kr
# 18    3 195 000 kr
# 19    2 795 000 kr
# 20    3 795 000 kr
# 21    4 595 000 kr
# 22    5 995 000 kr
# 23    5 495 000 kr
# 24    4 995 000 kr
# 25    5 195 000 kr
# 26    3 595 000 kr
# 27    3 295 000 kr
# 28    2 900 000 kr
# 29    1 995 000 kr
# 30    3 895 000 kr
# 31    2 195 000 kr
# 32    3 995 000 kr
# 33    2 450 000 kr
# 34    4 650 000 kr
# 35    3 495 000 kr
# 36    4 000 000 kr
# 37    6 000 000 kr
# 38    2 995 000 kr
# 39    1 580 000 kr
# 40    3 995 000 kr
# 41    2 250 000 kr
# 42    3 050 000 kr
# 43    4 695 000 kr
# 44    2 395 000 kr
# 45    6 995 000 kr
# 46    4 500 000 kr
# 47    4 450 000 kr
# 48    2 550 000 kr
# 49    2 850 000 kr
# 50    4 800 000 kr
# 51    6 250 000 kr
# 52    2 595 000 kr
# 53    3 175 000 kr
# 54    1 890 000 kr
# 55    4 995 000 kr
# 56    2 400 000 kr
# 57    3 995 000 kr
# Name: price, dtype: object

# %%
df.filter(['address','price'],axis=1)
# Out:
#                                 address         price
# 0            Krysshammarvägen 30, vån 4  3 495 000 kr
# 1                         Armégatan 11b  4 995 000 kr
# 2                  Johan Enbergs väg 64  6 450 000 kr
# 3                         Storgatan 72A  2 390 000 kr
# 4                         Armégatan 11A  2 995 000 kr
# 5             Krysshammarvägen 32, 5tr!  4 495 000 kr
# 6                    Krysshammarvägen 4  2 395 000 kr
# 7                        Polhemsgatan 4  3 895 000 kr
# 8                         Storgatan 70B  2 295 000 kr
# 9                   Krysshammarvägen 22  2 095 000 kr
# 10          Göran Perssons Väg 29, 2 tr  3 995 000 kr
# 11                        Storgatan 72A  4 995 000 kr
# 12                     Jungfrudansen 52  2 795 000 kr
# 13                      Jungfrudansen 7  1 950 000 kr
# 14                     Jungfrudansen 50  3 995 000 kr
# 15                 Arvid Tydéns allé 26  3 595 000 kr
# 16                          Bangatan 1D  1 650 000 kr
# 17      Armégatan 25, Högt upp i huset!  4 995 000 kr
# 18      Armégatan 3,  Högt upp i huset!  3 195 000 kr
# 19              Jungfrudansen 42, vån 2  2 795 000 kr
# 20           Johan Enbergs väg 15, 1 tr  3 795 000 kr
# 21         Kristinelundsvägen 34, vån 1  4 595 000 kr
# 22        Arvid Tydéns Allé 28, vån 4/4  5 995 000 kr
# 23                Johan Enbergs väg 54B  5 495 000 kr
# 24                    Jonstorpsvägen 28  4 995 000 kr
# 25           Johan Enbergs väg 9, vån 7  5 195 000 kr
# 26                  Armégatan 25, vån 6  3 595 000 kr
# 27                        Wiboms väg 12  3 295 000 kr
# 28                        Diktarvägen 8  2 900 000 kr
# 29                Kristinelundsvägen 46  1 995 000 kr
# 30               Jungfrudansen 40, 2 tr  3 895 000 kr
# 31                     Infanterigatan 5  2 195 000 kr
# 32                   Wiboms Väg 2, 6 tr  3 995 000 kr
# 33                    Infanterigatan 17  2 450 000 kr
# 34                 Polhemsgatan 4, 3 tr  4 650 000 kr
# 35          Johan Enbergs väg 28, vån 5  3 495 000 kr
# 36               Jungfrudansen 12, 2 tr  4 000 000 kr
# 37               Huvudstagatan 14A, 3tr  6 000 000 kr
# 38                 Oskarsrogatan 5, 7tr  2 995 000 kr
# 39                     Infanterigatan 9  1 580 000 kr
# 40                        Storgatan 62C  3 995 000 kr
# 41  Kapellgatan 18 / Ingentingsgatan 14  2 250 000 kr
# 42                    Infanterigatan 25  3 050 000 kr
# 43      Armégatan 5, HÖGST UPP I HUSET!  4 695 000 kr
# 44                 Kapellgatan 20, 2 tr  2 395 000 kr
# 45                     Jungfrudansen 44  6 995 000 kr
# 46                           Bygatan 25  4 500 000 kr
# 47                Trubadurvägen 3, 2 tr  4 450 000 kr
# 48                     Bygatan 21, 2 tr  2 550 000 kr
# 49                 Armégatan 28, vån 3!  2 850 000 kr
# 50                  Wiboms Väg 6, 7 tr   4 800 000 kr
# 51                 Släggbacken 7, vån 6  6 250 000 kr
# 52                    Infanterigatan 17  2 595 000 kr
# 53                     Jungfrudansen 11  3 175 000 kr
# 54              Karolinagatan 1, vån 2!  1 890 000 kr
# 55                      Trubadurvägen 3  4 995 000 kr
# 56                     Järnvägsgatan 2E  2 400 000 kr
# 57     Arvid Tydéns allé 18, vån 6 av 6  3 995 000 kr

# %% [markdown]
# ----- using the gui map box request -----

# %%
url = "https://www.hemnet.se/bostader/bbox?bbox=59.33561378405482,17.93920733002009:59.36344287627166,18.05456377533259&search_key=10bbfe7032b0c082b18040b1094045e7e59cc941"

params={
    'bbox':'59.247127100450335,17.76513093234948:59.35859632184681,18.403711254615104',
    'search_key':'57938136258b743b4bfb313c013169b07ef4cffd'
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'
}

# %%
response = requests.request("GET", url, headers=headers, data=payload, params=params)

j=response.json()['properties']

# %%
df2=pd.json_normalize(j, max_level=1)
df2
# Out:
#          id                     coordinate                           address  \
# 0  18687869       [59.3083572, 18.0818329]                     Ringvägen 130
# 1  19185098       [59.3094864, 18.0841122]                     Ringvägen 153
# 2  19073739       [59.3096581, 18.0841846]               Ringvägen 155, 4 tr
# 3  19189476        [59.307312, 18.0700874]                      Ringvägen 86
# 4  19065856       [59.3072853, 18.0699234]                Ringvägen 84, 4 tr
# 5  19039408         [59.3084564, 18.06627]                 Ringvägen 87A 3tr
# 6  18649666  [59.3090594643, 18.062006292]    Ringvägen 54, Accepterat pris!
# 7  19008195            [59.30846, 18.0825]    Ringvägen 138, ACCEPTERAT PRIS
# 8  18966116       [59.3184624, 18.0507011]  Ringvägen 11A - ACCEPTERAT PRIS!
# 9  19221316          [59.308773, 18.06481]                Ringvägen 79, 2 tr
#
#        location_name           typeSummary     iconName  project  \
# 0  Stockholms kommun  Bostadsrättslägenhet  bostadsratt    False
# 1  Stockholms kommun  Bostadsrättslägenhet  bostadsratt    False
# 2  Stockholms kommun  Bostadsrättslägenhet  bostadsratt    False
# 3  Stockholms kommun  Bostadsrättslägenhet  bostadsratt    False
# 4  Stockholms kommun  Bostadsrättslägenhet  bostadsratt    False
# 5  Stockholms kommun  Bostadsrättslägenhet  bostadsratt    False
# 6  Stockholms kommun  Bostadsrättslägenhet  bostadsratt    False
# 7  Stockholms kommun  Bostadsrättslägenhet  bostadsratt    False
# 8  Stockholms kommun  Bostadsrättslägenhet  bostadsratt    False
# 9  Stockholms kommun  Bostadsrättslägenhet  bostadsratt    False
#
#    new_construction  ongoing_bidding  foreclosure  ...  \
# 0             False            False        False  ...
# 1             False            False        False  ...
# 2             False            False        False  ...
# 3             False            False        False  ...
# 4             False            False        False  ...
# 5             False            False        False  ...
# 6             False            False        False  ...
# 7             False            False        False  ...
# 8             False            False        False  ...
# 9             False            False        False  ...
#
#                       broker_agency_name  \
# 0                      MOHV Stockholm AB
# 1                         Historiska Hem
# 2                          Södermäklarna
# 3       Alicia Edelman Fastighetsmäkleri
# 4                          Södermäklarna
# 5                     Bjurfors Södermalm
# 6  Fastighetsbyrån Stockholm - Södermalm
# 7       Erik Olsson Fastighetsförmedling
# 8     HusmanHagberg Södermalm/Gamla Stan
# 9                     Bjurfors Södermalm
#
#                              locations_string should_display_showings  \
# 0                Södermalm, Stockholms kommun                   False
# 1                Södermalm, Stockholms kommun                   False
# 2                Södermalm, Stockholms kommun                   False
# 3                Södermalm, Stockholms kommun                   False
# 4       Södermalm Katarina, Stockholms kommun                   False
# 5       Södermalm Katarina, Stockholms kommun                   False
# 6                 Katarina, Stockholms kommun                   False
# 7                Södermalm, Stockholms kommun                   False
# 8  Södermalm - Zinkensdamm, Stockholms kommun                   False
# 9       Södermalm Katarina, Stockholms kommun                   False
#
#    should_highlight_showings  \
# 0                      False
# 1                      False
# 2                      False
# 3                       True
# 4                      False
# 5                      False
# 6                      False
# 7                      False
# 8                      False
# 9                      False
#
#                                   living_space.table trackingData.listingId  \
# 0  {'living_area': '21,5 m²', 'supplemental_area'...               18687869
# 1  {'living_area': '33 m²', 'supplemental_area': ...               19185098
# 2  {'living_area': '37 m²', 'supplemental_area': ...               19073739
# 3  {'living_area': '38 m²', 'supplemental_area': ...               19189476
# 4  {'living_area': '45 m²', 'supplemental_area': ...               19065856
# 5  {'living_area': '47 m²', 'supplemental_area': ...               19039408
# 6  {'living_area': '51 m²', 'supplemental_area': ...               18649666
# 7  {'living_area': '52 m²', 'supplemental_area': ...               19008195
# 8  {'living_area': '92 m²', 'supplemental_area': ...               18966116
# 9  {'living_area': '109,4 m²', 'supplemental_area...               19221316
#
#   trackingData.listingType  trackingData.listingPackageType  \
# 0           common_listing                            basic
# 1           common_listing                            basic
# 2           common_listing                             plus
# 3           common_listing                             plus
# 4           common_listing                             plus
# 5           common_listing                          premium
# 6           common_listing                            basic
# 7           common_listing                          premium
# 8           common_listing                            basic
# 9           common_listing                            basic
#
#    trackingData.listingState trackingData.listingStatus
# 0                     active                   for_sale
# 1                     active                   for_sale
# 2                     active                   for_sale
# 3                     active                   for_sale
# 4                     active                   for_sale
# 5                     active                   for_sale
# 6                     active                   for_sale
# 7                     active                   for_sale
# 8                     active                   for_sale
# 9                     active                   for_sale
#
# [10 rows x 38 columns]

# %% [markdown]
# ---- using HTML response ----

# %%
import requests

url = "https://www.hemnet.se/bostader?"
params= {
    'location_ids[]':473498,
    'item_types[]':'bostadsratt'
}
payload={}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'
}

response = requests.request("GET", url, headers=headers, data=payload, params=params)

# %% [markdown]
# --------- w beautiful soup ------------

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
#> div.listing-card__information-container > div > div.listing-card__header > div.listing-card__address > h2')

cards=soup.select('#result > ul > li > a')

for card in cards:
    print(card.attrs['href'])
    print(card)
# Out:
# https://www.hemnet.se/bostad/lagenhet-5rum-huvudsta-solna-kommun-slaggbacken-7,-van-6-18967020
# <a class="js-listing-card-link listing-card" data-target-blank="true" href="https://www.hemnet.se/bostad/lagenhet-5rum-huvudsta-solna-kommun-slaggbacken-7,-van-6-18967020">
# <div class="listing-card__images-container">
# <div class="listing-card__image-container">
# <img alt="Släggbacken 7, vån 6, Huvudsta, Solna kommun" class="js-lazy-load listing-card__image listing-card__image--big" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/listing_card/e0/17/e017bbbe60e4c35e33e67897f4fbcbb1.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# <div class="listing-label-paid-placement">
# <div class="listing-label listing-label--state listing-label--paid_placement qa-listing-label-state-paid_placement">
# <span class="listing-label__text">Betald placering</span>
# </div>
# </div>
# <div class="listing-card__media-attachments-container">
# </div>
# <div class="listing-card__state-labels-container">
# <div class="listing-card__state-label-container">
# <div class="listing-label listing-label--state listing-label--toplisting listing-label--icon-only qa-listing-label-state-toplisting">
# <span class="state-label-icon--toplisting state-label-icon--without-margin"></span>
# </div>
# </div>
# <div class="listing-card__state-label-container">
# <div class="listing-label listing-label--state listing-label--highlighted_showing qa-listing-label-state-highlighted_showing">
# <span class="state-label-icon--highlighted_showing"></span>
# <span class="listing-label__text">Sön 16 okt kl 12:00</span>
# </div>
# </div>
# </div>
# <div class="listing-card__save-button__container">
# <div aria-label="Spara" class="js-save-listing" data-in-beta-authentication-experiment="false" data-listing-id="18967020" data-listing-is-saved="false" data-listing-user-saved="false" data-tracking-category="resultatvy">
# <div class="save-listing-button save-listing-button--only-icon">
# <span class="save-listing-button__unsaved-icon">
# <svg viewbox="0 0 20 18" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M17.906 1.298C15.648-.654 12.16-.36 10 1.901 7.84-.361 4.352-.658 2.094 1.298-.844 3.841-.414 7.986 1.68 10.183l6.851 7.178a2.01 2.01 0 002.937.004l6.852-7.178c2.09-2.197 2.528-6.342-.414-8.889z" fill="#007e47"></path><path d="M2.094 1.298C4.352-.658 7.84-.36 10 1.901c2.16-2.262 5.648-2.555 7.906-.603 2.942 2.547 2.504 6.692.414 8.89l-6.851 7.177a2.01 2.01 0 01-2.938-.004L1.68 10.183c-2.094-2.197-2.524-6.342.414-8.885zm14.605 1.474c-1.511-1.309-3.855-1.12-5.332.426L10 4.632 8.633 3.198C7.164 1.66 4.82 1.463 3.3 2.776c-2 1.732-1.711 4.56-.285 6.054l6.851 7.178c.094.096.172.096.266 0l6.851-7.178c1.414-1.482 1.711-4.326-.285-6.058z" fill="#013a14"></path></g></svg>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="listing-card__thumbnails-container qa-listing-thumbnails">
# <img alt="" class="listing-card__thumbnail-image js-lazy-load" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/itemgallery_M/05/37/0537e0581df8e8982bb783fcd34cb3d1.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# <img alt="" class="listing-card__thumbnail-image js-lazy-load" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/itemgallery_M/63/f3/63f3aa023dfcbee260d61be5adb1e53c.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# </div>
# </div>
# <div class="listing-card__information-container">
# <div class="listing-card__information-content">
# <div class="listing-card__header">
# <div class="listing-card__address">
# <h2 class="listing-card__street-address qa-listing-title">
#         Släggbacken 7, vån 6
#       </h2>
# <div class="listing-card__location">
# <span class="listing-card__property-type-icon">
# <svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><title>Lägenhet</title><desc><span class="svg-icon__fallback-text">Lägenhet</span></desc><path class="svg-icon__shape" d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="listing-card__location-name">
#           Huvudsta, Solna kommun
#         </span>
# </div>
# </div>
# <div class="listing-card__broker-logo">
# <img alt="Länsförsäkringar Fastighetsförmedling Solna" class="js-lazy-load" data-object-fit="contain" data-src="https://bilder.hemnet.se/images/broker_logo_2/73/c6/73c63376473b74a25e13711a82fcae60.png" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# </div>
# </div>
# <div class="listing-card__attributes-container">
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--primary">
#           6 250 000 kr
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#                153 m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#           5 rum
#         </div>
# </div>
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--fee">
#           7 819 kr/mån
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--square-meter-price">
#           40 850 kr/m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--">
# </div>
# </div>
# </div>
# <div class="listing-card__description-container listing-card__description--desktop">
# <p class="listing-card__description listing-card__description--six-lines">
#     *****AV SÄLJARNA ACCEPTERAT PRIS*****
#
# - Gavelläge
# - 153 kvm möjlig 6:a!
# - Stabil förening
# - Närhet till allt
# - Renoverad
# - Milsvid utsikt från balkong
#
# ÄNTLIGEN så kommer en av de största lägenheterna som finns på Släggbacken ut till försäljning!
# Ett tillfälle som kommer ytterst sällan, och där lägenheten dessutom redo att flytta rakt in i.
# Lägenhetens 153 kvm disponeras med du...
#   </p>
# </div>
# <div class="listing-card__labels-container">
# <ul class="hcl-labels-list hcl-labels-list--row-direction">
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--product hcl-label--on-white-background">
#             Premium
#           </span>
# </li>
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Balkong
#           </span>
# </li>
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Hiss
#           </span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </a>
# https://www.hemnet.se/bostad/lagenhet-3rum-huvudsta-solna-kommun-krysshammarvagen-30,-van-4-19204395
# <a class="js-listing-card-link listing-card" data-target-blank="true" href="https://www.hemnet.se/bostad/lagenhet-3rum-huvudsta-solna-kommun-krysshammarvagen-30,-van-4-19204395">
# <div class="listing-card__images-container">
# <div class="listing-card__image-container">
# <img alt="Krysshammarvägen 30, vån 4, Huvudsta, Solna kommun" class="js-lazy-load listing-card__image" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/listing_card/ce/8d/ce8ddebed41485c14af316cd9dfbcf5e.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# <div class="listing-card__media-attachments-container">
# </div>
# <div class="listing-card__state-labels-container">
# </div>
# <div class="listing-card__save-button__container">
# <div aria-label="Spara" class="js-save-listing" data-in-beta-authentication-experiment="false" data-listing-id="19204395" data-listing-is-saved="false" data-listing-user-saved="false" data-tracking-category="resultatvy">
# <div class="save-listing-button save-listing-button--only-icon">
# <span class="save-listing-button__unsaved-icon">
# <svg viewbox="0 0 20 18" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M17.906 1.298C15.648-.654 12.16-.36 10 1.901 7.84-.361 4.352-.658 2.094 1.298-.844 3.841-.414 7.986 1.68 10.183l6.851 7.178a2.01 2.01 0 002.937.004l6.852-7.178c2.09-2.197 2.528-6.342-.414-8.889z" fill="#007e47"></path><path d="M2.094 1.298C4.352-.658 7.84-.36 10 1.901c2.16-2.262 5.648-2.555 7.906-.603 2.942 2.547 2.504 6.692.414 8.89l-6.851 7.177a2.01 2.01 0 01-2.938-.004L1.68 10.183c-2.094-2.197-2.524-6.342.414-8.885zm14.605 1.474c-1.511-1.309-3.855-1.12-5.332.426L10 4.632 8.633 3.198C7.164 1.66 4.82 1.463 3.3 2.776c-2 1.732-1.711 4.56-.285 6.054l6.851 7.178c.094.096.172.096.266 0l6.851-7.178c1.414-1.482 1.711-4.326-.285-6.058z" fill="#013a14"></path></g></svg>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="listing-card__information-container">
# <div class="listing-card__information-content">
# <div class="listing-card__header">
# <div class="listing-card__address">
# <h2 class="listing-card__street-address qa-listing-title">
#         Krysshammarvägen 30, vån 4
#       </h2>
# <div class="listing-card__location">
# <span class="listing-card__property-type-icon">
# <svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><title>Lägenhet</title><desc><span class="svg-icon__fallback-text">Lägenhet</span></desc><path class="svg-icon__shape" d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="listing-card__location-name">
#           Huvudsta, Solna kommun
#         </span>
# </div>
# </div>
# <div class="listing-card__broker-logo">
# <img alt="Länsförsäkringar Fastighetsförmedling Solna" class="js-lazy-load" data-object-fit="contain" data-src="https://bilder.hemnet.se/images/broker_logo_2/73/c6/73c63376473b74a25e13711a82fcae60.png" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# </div>
# </div>
# <div class="listing-card__attributes-container">
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--primary">
#           3 495 000 kr
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#                82,3 m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#           3 rum
#         </div>
# </div>
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--fee">
#           4 502 kr/mån
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--square-meter-price">
#           42 467 kr/m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--">
# </div>
# </div>
# </div>
# <div class="listing-card__description-container listing-card__description--desktop">
# <p class="listing-card__description">
#     Välkommen till denna fräscha trea med genomgående planlösning. Bost...
#   </p>
# </div>
# <div class="listing-card__labels-container">
# <ul class="hcl-labels-list hcl-labels-list--row-direction">
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Balkong
#           </span>
# </li>
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Hiss
#           </span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </a>
# https://www.hemnet.se/bostad/lagenhet-3rum-solna-kommun-armegatan-11b-19197055
# <a class="js-listing-card-link listing-card" data-target-blank="true" href="https://www.hemnet.se/bostad/lagenhet-3rum-solna-kommun-armegatan-11b-19197055">
# <div class="listing-card__images-container">
# <div class="listing-card__image-container">
# <img alt="Armégatan 11b, Solna, Solna kommun" class="js-lazy-load listing-card__image listing-card__image--big" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/listing_card/54/84/5484ec5029a1aa6f801426740e61be93.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# <div class="listing-card__media-attachments-container">
# </div>
# <div class="listing-card__state-labels-container">
# <div class="listing-card__state-label-container">
# <div class="listing-label listing-label--state listing-label--highlighted_showing qa-listing-label-state-highlighted_showing">
# <span class="state-label-icon--highlighted_showing"></span>
# <span class="listing-label__text">Tor 20 okt</span>
# </div>
# </div>
# </div>
# <div class="listing-card__save-button__container">
# <div aria-label="Spara" class="js-save-listing" data-in-beta-authentication-experiment="false" data-listing-id="19197055" data-listing-is-saved="false" data-listing-user-saved="false" data-tracking-category="resultatvy">
# <div class="save-listing-button save-listing-button--only-icon">
# <span class="save-listing-button__unsaved-icon">
# <svg viewbox="0 0 20 18" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M17.906 1.298C15.648-.654 12.16-.36 10 1.901 7.84-.361 4.352-.658 2.094 1.298-.844 3.841-.414 7.986 1.68 10.183l6.851 7.178a2.01 2.01 0 002.937.004l6.852-7.178c2.09-2.197 2.528-6.342-.414-8.889z" fill="#007e47"></path><path d="M2.094 1.298C4.352-.658 7.84-.36 10 1.901c2.16-2.262 5.648-2.555 7.906-.603 2.942 2.547 2.504 6.692.414 8.89l-6.851 7.177a2.01 2.01 0 01-2.938-.004L1.68 10.183c-2.094-2.197-2.524-6.342.414-8.885zm14.605 1.474c-1.511-1.309-3.855-1.12-5.332.426L10 4.632 8.633 3.198C7.164 1.66 4.82 1.463 3.3 2.776c-2 1.732-1.711 4.56-.285 6.054l6.851 7.178c.094.096.172.096.266 0l6.851-7.178c1.414-1.482 1.711-4.326-.285-6.058z" fill="#013a14"></path></g></svg>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="listing-card__thumbnails-container qa-listing-thumbnails">
# <img alt="" class="listing-card__thumbnail-image js-lazy-load" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/itemgallery_M/21/b0/21b050d5ba697c4bec89ecdb0b1c372b.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# <img alt="" class="listing-card__thumbnail-image js-lazy-load" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/itemgallery_M/55/c1/55c1c910605a7dbc0a802fa986ef9dd2.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# </div>
# </div>
# <div class="listing-card__information-container">
# <div class="listing-card__information-content">
# <div class="listing-card__header">
# <div class="listing-card__address">
# <h2 class="listing-card__street-address qa-listing-title">
#         Armégatan 11b
#       </h2>
# <div class="listing-card__location">
# <span class="listing-card__property-type-icon">
# <svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><title>Lägenhet</title><desc><span class="svg-icon__fallback-text">Lägenhet</span></desc><path class="svg-icon__shape" d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="listing-card__location-name">
#           Solna, Solna kommun
#         </span>
# </div>
# </div>
# <div class="listing-card__broker-logo">
# <img alt="Urban by ESNY" class="js-lazy-load" data-object-fit="contain" data-src="https://bilder.hemnet.se/images/broker_logo_2/db/96/db961eb1de419648217e55fccf278bf6.png" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# </div>
# </div>
# <div class="listing-card__attributes-container">
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--primary">
#           4 995 000 kr
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#                78 m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#           3 rum
#         </div>
# </div>
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--fee">
#           4 225 kr/mån
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--square-meter-price">
#           64 038 kr/m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--">
# </div>
# </div>
# </div>
# <div class="listing-card__description-container listing-card__description--desktop">
# <p class="listing-card__description listing-card__description--six-lines">
#     Högt upp i en av Solnas unikaste föreningar finner ni denna fantastiska trea med en standard utöver det vanliga! Lägenheten kännetecknas av dess optimala planlösning, påkostade materialval samt goda förvaringsmöjligheter. Välskött förening med god ekonomi. Föreningen har förmodligen de bästa gemensamma utrymmen i hela Solna med bland annat rymligt uppvärmd spabad, bastu, garage, ca 100 kvm takt...
#   </p>
# </div>
# <div class="listing-card__labels-container">
# <ul class="hcl-labels-list hcl-labels-list--row-direction">
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--product hcl-label--on-white-background">
#             Premium
#           </span>
# </li>
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Balkong
#           </span>
# </li>
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Hiss
#           </span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </a>
# https://www.hemnet.se/bostad/lagenhet-5rum-vastra-skogen-solna-kommun-johan-enbergs-vag-64-19219416
# <a class="js-listing-card-link listing-card" data-target-blank="true" href="https://www.hemnet.se/bostad/lagenhet-5rum-vastra-skogen-solna-kommun-johan-enbergs-vag-64-19219416">
# <div class="listing-card__images-container">
# <div class="listing-card__image-container">
# <img alt="Johan Enbergs väg 64, Västra Skogen, Solna kommun" class="js-lazy-load listing-card__image" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/listing_card/94/a1/94a18637e789a967aac4e2ad97456b21.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# <div class="listing-card__media-attachments-container">
# </div>
# <div class="listing-card__state-labels-container">
# </div>
# <div class="listing-card__save-button__container">
# <div aria-label="Spara" class="js-save-listing" data-in-beta-authentication-experiment="false" data-listing-id="19219416" data-listing-is-saved="false" data-listing-user-saved="false" data-tracking-category="resultatvy">
# <div class="save-listing-button save-listing-button--only-icon">
# <span class="save-listing-button__unsaved-icon">
# <svg viewbox="0 0 20 18" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M17.906 1.298C15.648-.654 12.16-.36 10 1.901 7.84-.361 4.352-.658 2.094 1.298-.844 3.841-.414 7.986 1.68 10.183l6.851 7.178a2.01 2.01 0 002.937.004l6.852-7.178c2.09-2.197 2.528-6.342-.414-8.889z" fill="#007e47"></path><path d="M2.094 1.298C4.352-.658 7.84-.36 10 1.901c2.16-2.262 5.648-2.555 7.906-.603 2.942 2.547 2.504 6.692.414 8.89l-6.851 7.177a2.01 2.01 0 01-2.938-.004L1.68 10.183c-2.094-2.197-2.524-6.342.414-8.885zm14.605 1.474c-1.511-1.309-3.855-1.12-5.332.426L10 4.632 8.633 3.198C7.164 1.66 4.82 1.463 3.3 2.776c-2 1.732-1.711 4.56-.285 6.054l6.851 7.178c.094.096.172.096.266 0l6.851-7.178c1.414-1.482 1.711-4.326-.285-6.058z" fill="#013a14"></path></g></svg>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="listing-card__information-container">
# <div class="listing-card__information-content">
# <div class="listing-card__header">
# <div class="listing-card__address">
# <h2 class="listing-card__street-address qa-listing-title">
#         Johan Enbergs väg 64
#       </h2>
# <div class="listing-card__location">
# <span class="listing-card__property-type-icon">
# <svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><title>Lägenhet</title><desc><span class="svg-icon__fallback-text">Lägenhet</span></desc><path class="svg-icon__shape" d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="listing-card__location-name">
#           Västra Skogen, Solna kommun
#         </span>
# </div>
# </div>
# <div class="listing-card__broker-logo">
# <img alt="Notar" class="js-lazy-load" data-object-fit="contain" data-src="https://bilder.hemnet.se/images/broker_logo_2/20/cc/20cc4b76ca46cc2250eb9f2561a63e8c.png" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# </div>
# </div>
# <div class="listing-card__attributes-container">
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--primary">
#           6 450 000 kr
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#                118 m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#           5 rum
#         </div>
# </div>
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--fee">
#           5 588 kr/mån
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--square-meter-price">
#           54 661 kr/m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--">
# </div>
# </div>
# </div>
# <div class="listing-card__description-container listing-card__description--desktop">
# <p class="listing-card__description">
#     Välkommen till denna härliga lägenhet med naturen och Ulvsundasjön ...
#   </p>
# </div>
# <div class="listing-card__labels-container">
# <ul class="hcl-labels-list hcl-labels-list--row-direction">
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Balkong
#           </span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </a>
# https://www.hemnet.se/bostad/lagenhet-1,5rum-huvudsta-centrum-solna-kommun-storgatan-72a-18743994
# <a class="js-listing-card-link listing-card" data-target-blank="true" href="https://www.hemnet.se/bostad/lagenhet-1,5rum-huvudsta-centrum-solna-kommun-storgatan-72a-18743994">
# <div class="listing-card__images-container">
# <div class="listing-card__image-container">
# <img alt="Storgatan 72A, Huvudsta centrum, Solna kommun" class="js-lazy-load listing-card__image listing-card__image--big" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/listing_card/8b/88/8b8865e803a4dc512ab9bcf01d624deb.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# <div class="listing-card__media-attachments-container">
# <div class="listing-card__media-attachments-label-container">
# <div class="listing-label listing-label--media_attachment listing-label--video listing-label--icon-only qa-listing-label-media_attachment-video">
# <span class="media-attachment-label-icon--video">
# <i class="fa fa-video-camera"></i>
# </span>
# </div>
# </div>
# </div>
# <div class="listing-card__state-labels-container">
# <div class="listing-card__state-label-container">
# <div class="listing-label listing-label--state listing-label--highlighted_showing qa-listing-label-state-highlighted_showing">
# <span class="state-label-icon--highlighted_showing"></span>
# <span class="listing-label__text">Sön 16 okt kl 13:00</span>
# </div>
# </div>
# </div>
# <div class="listing-card__save-button__container">
# <div aria-label="Spara" class="js-save-listing" data-in-beta-authentication-experiment="false" data-listing-id="18743994" data-listing-is-saved="false" data-listing-user-saved="false" data-tracking-category="resultatvy">
# <div class="save-listing-button save-listing-button--only-icon">
# <span class="save-listing-button__unsaved-icon">
# <svg viewbox="0 0 20 18" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M17.906 1.298C15.648-.654 12.16-.36 10 1.901 7.84-.361 4.352-.658 2.094 1.298-.844 3.841-.414 7.986 1.68 10.183l6.851 7.178a2.01 2.01 0 002.937.004l6.852-7.178c2.09-2.197 2.528-6.342-.414-8.889z" fill="#007e47"></path><path d="M2.094 1.298C4.352-.658 7.84-.36 10 1.901c2.16-2.262 5.648-2.555 7.906-.603 2.942 2.547 2.504 6.692.414 8.89l-6.851 7.177a2.01 2.01 0 01-2.938-.004L1.68 10.183c-2.094-2.197-2.524-6.342.414-8.885zm14.605 1.474c-1.511-1.309-3.855-1.12-5.332.426L10 4.632 8.633 3.198C7.164 1.66 4.82 1.463 3.3 2.776c-2 1.732-1.711 4.56-.285 6.054l6.851 7.178c.094.096.172.096.266 0l6.851-7.178c1.414-1.482 1.711-4.326-.285-6.058z" fill="#013a14"></path></g></svg>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="listing-card__thumbnails-container qa-listing-thumbnails">
# <img alt="" class="listing-card__thumbnail-image js-lazy-load" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/itemgallery_M/17/35/17355a54e12d37c374d6bdbb356dd928.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# <img alt="" class="listing-card__thumbnail-image js-lazy-load" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/itemgallery_M/b7/5e/b75ed63c64b2ff8fc0b38dc738c2212b.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# </div>
# </div>
# <div class="listing-card__information-container">
# <div class="listing-card__information-content">
# <div class="listing-card__header">
# <div class="listing-card__address">
# <h2 class="listing-card__street-address qa-listing-title">
#         Storgatan 72A
#       </h2>
# <div class="listing-card__location">
# <span class="listing-card__property-type-icon">
# <svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><title>Lägenhet</title><desc><span class="svg-icon__fallback-text">Lägenhet</span></desc><path class="svg-icon__shape" d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="listing-card__location-name">
#           Huvudsta centrum, Solna kommun
#         </span>
# </div>
# </div>
# <div class="listing-card__broker-logo">
# <img alt="SthlmFast" class="js-lazy-load" data-object-fit="contain" data-src="https://bilder.hemnet.se/images/broker_logo_2/90/7b/907bd968a9dbf3a35100ba71123bd930.png" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# </div>
# </div>
# <div class="listing-card__attributes-container">
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--primary">
#           2 390 000 kr
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#                44 m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#           1,5 rum
#         </div>
# </div>
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--fee">
#           2 813 kr/mån
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--square-meter-price">
#           54 318 kr/m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--">
# </div>
# </div>
# </div>
# <div class="listing-card__description-container listing-card__description--desktop">
# <p class="listing-card__description listing-card__description--six-lines">
#     - Flera extra tillval i bostaden
# - Stor &amp; inglasad balkong om ca 9 kvm
# - Modernt &amp; fullutrustat kök
# - Stort badrum med tvättmaskin &amp; golvvärme
# - Förråd &amp; klädkammare
# - Mycket bra kommunikationer
# - Närhet till vatten &amp; grönområden
# - Stabil förening med god ekonomi
#
# Perfekt planerad 1,5:a i toppskick med stor inglasad balkong, härlig utsikt och genomtänkt planlösning. Öppet mellan var...
#   </p>
# </div>
# <div class="listing-card__labels-container">
# <ul class="hcl-labels-list hcl-labels-list--row-direction">
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--product hcl-label--on-white-background">
#             Premium
#           </span>
# </li>
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Balkong
#           </span>
# </li>
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Hiss
#           </span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </a>
# https://www.hemnet.se/bostad/lagenhet-2rum-vastra-skogen-ingenting-solna-kommun-armegatan-11a-19198756
# <a class="js-listing-card-link listing-card" data-target-blank="true" href="https://www.hemnet.se/bostad/lagenhet-2rum-vastra-skogen-ingenting-solna-kommun-armegatan-11a-19198756">
# <div class="listing-card__images-container">
# <div class="listing-card__image-container">
# <img alt="Armégatan 11A, Västra Skogen/Ingenting, Solna kommun" class="js-lazy-load listing-card__image listing-card__image--big" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/listing_card/87/a3/87a3a31337652920d44873b012dfd228.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# <div class="listing-card__media-attachments-container">
# </div>
# <div class="listing-card__state-labels-container">
# <div class="listing-card__state-label-container">
# <div class="listing-label listing-label--state listing-label--highlighted_showing qa-listing-label-state-highlighted_showing">
# <span class="state-label-icon--highlighted_showing"></span>
# <span class="listing-label__text">Sön 16 okt kl 13:15</span>
# </div>
# </div>
# </div>
# <div class="listing-card__save-button__container">
# <div aria-label="Spara" class="js-save-listing" data-in-beta-authentication-experiment="false" data-listing-id="19198756" data-listing-is-saved="false" data-listing-user-saved="false" data-tracking-category="resultatvy">
# <div class="save-listing-button save-listing-button--only-icon">
# <span class="save-listing-button__unsaved-icon">
# <svg viewbox="0 0 20 18" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M17.906 1.298C15.648-.654 12.16-.36 10 1.901 7.84-.361 4.352-.658 2.094 1.298-.844 3.841-.414 7.986 1.68 10.183l6.851 7.178a2.01 2.01 0 002.937.004l6.852-7.178c2.09-2.197 2.528-6.342-.414-8.889z" fill="#007e47"></path><path d="M2.094 1.298C4.352-.658 7.84-.36 10 1.901c2.16-2.262 5.648-2.555 7.906-.603 2.942 2.547 2.504 6.692.414 8.89l-6.851 7.177a2.01 2.01 0 01-2.938-.004L1.68 10.183c-2.094-2.197-2.524-6.342.414-8.885zm14.605 1.474c-1.511-1.309-3.855-1.12-5.332.426L10 4.632 8.633 3.198C7.164 1.66 4.82 1.463 3.3 2.776c-2 1.732-1.711 4.56-.285 6.054l6.851 7.178c.094.096.172.096.266 0l6.851-7.178c1.414-1.482 1.711-4.326-.285-6.058z" fill="#013a14"></path></g></svg>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="listing-card__information-container">
# <div class="listing-card__information-content">
# <div class="listing-card__header">
# <div class="listing-card__address">
# <h2 class="listing-card__street-address qa-listing-title">
#         Armégatan 11A
#       </h2>
# <div class="listing-card__location">
# <span class="listing-card__property-type-icon">
# <svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><title>Lägenhet</title><desc><span class="svg-icon__fallback-text">Lägenhet</span></desc><path class="svg-icon__shape" d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="listing-card__location-name">
#           Västra Skogen/Ingenting, Solna kommun
#         </span>
# </div>
# </div>
# <div class="listing-card__broker-logo">
# <img alt="MOHV Solna" class="js-lazy-load" data-object-fit="contain" data-src="https://bilder.hemnet.se/images/broker_logo_2/70/20/7020aafa6771b71d9a321b629ddbd01c.png" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# </div>
# </div>
# <div class="listing-card__attributes-container">
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--primary">
#           2 995 000 kr
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#                60 m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#           2 rum
#         </div>
# </div>
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--fee">
#           3 250 kr/mån
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--square-meter-price">
#           49 917 kr/m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--">
# </div>
# </div>
# </div>
# <div class="listing-card__description-container listing-card__description--desktop">
# <p class="listing-card__description listing-card__description--two-lines">
#     // Stor balkong mot innergård // Fönster i två väderstreck // Rymlig tvåa med öppen planlösning // Nybyggt hem från 2016 // Garage på två plan i huset // Tillgång till spa och takterass i föreningen //
#
# Äntligen får jag presentera denna rymliga tvåa i populära The Lab!
# Perfekta boendet för så...
#   </p>
# </div>
# <div class="listing-card__labels-container">
# <ul class="hcl-labels-list hcl-labels-list--row-direction">
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--product hcl-label--on-white-background">
#             Plus
#           </span>
# </li>
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Balkong
#           </span>
# </li>
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Hiss
#           </span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </a>
# https://www.hemnet.se/bostad/lagenhet-5rum-solna-huvudsta-solna-kommun-krysshammarvagen-32,-5tr-19189918
# <a class="js-listing-card-link listing-card" data-target-blank="true" href="https://www.hemnet.se/bostad/lagenhet-5rum-solna-huvudsta-solna-kommun-krysshammarvagen-32,-5tr-19189918">
# <div class="listing-card__images-container">
# <div class="listing-card__image-container">
# <img alt="Krysshammarvägen 32, 5tr!, Solna / Huvudsta, Solna kommun" class="js-lazy-load listing-card__image listing-card__image--big" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/listing_card/ca/4c/ca4c0cb9e3351b47c4783fd3735e9e57.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# <div class="listing-card__media-attachments-container">
# </div>
# <div class="listing-card__state-labels-container">
# <div class="listing-card__state-label-container">
# <div class="listing-label listing-label--state listing-label--highlighted_showing qa-listing-label-state-highlighted_showing">
# <span class="state-label-icon--highlighted_showing"></span>
# <span class="listing-label__text">Sön 16 okt kl 12:00</span>
# </div>
# </div>
# </div>
# <div class="listing-card__save-button__container">
# <div aria-label="Spara" class="js-save-listing" data-in-beta-authentication-experiment="false" data-listing-id="19189918" data-listing-is-saved="false" data-listing-user-saved="false" data-tracking-category="resultatvy">
# <div class="save-listing-button save-listing-button--only-icon">
# <span class="save-listing-button__unsaved-icon">
# <svg viewbox="0 0 20 18" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M17.906 1.298C15.648-.654 12.16-.36 10 1.901 7.84-.361 4.352-.658 2.094 1.298-.844 3.841-.414 7.986 1.68 10.183l6.851 7.178a2.01 2.01 0 002.937.004l6.852-7.178c2.09-2.197 2.528-6.342-.414-8.889z" fill="#007e47"></path><path d="M2.094 1.298C4.352-.658 7.84-.36 10 1.901c2.16-2.262 5.648-2.555 7.906-.603 2.942 2.547 2.504 6.692.414 8.89l-6.851 7.177a2.01 2.01 0 01-2.938-.004L1.68 10.183c-2.094-2.197-2.524-6.342.414-8.885zm14.605 1.474c-1.511-1.309-3.855-1.12-5.332.426L10 4.632 8.633 3.198C7.164 1.66 4.82 1.463 3.3 2.776c-2 1.732-1.711 4.56-.285 6.054l6.851 7.178c.094.096.172.096.266 0l6.851-7.178c1.414-1.482 1.711-4.326-.285-6.058z" fill="#013a14"></path></g></svg>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="listing-card__information-container">
# <div class="listing-card__information-content">
# <div class="listing-card__header">
# <div class="listing-card__address">
# <h2 class="listing-card__street-address qa-listing-title">
#         Krysshammarvägen 32, 5tr!
#       </h2>
# <div class="listing-card__location">
# <span class="listing-card__property-type-icon">
# <svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><title>Lägenhet</title><desc><span class="svg-icon__fallback-text">Lägenhet</span></desc><path class="svg-icon__shape" d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="listing-card__location-name">
#           Solna / Huvudsta, Solna kommun
#         </span>
# </div>
# </div>
# <div class="listing-card__broker-logo">
# <img alt="BOSTHLM Älvsjö" class="js-lazy-load" data-object-fit="contain" data-src="https://bilder.hemnet.se/images/broker_logo_2/09/8d/098d01e00641ae617706acaf23bb6915.png" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# </div>
# </div>
# <div class="listing-card__attributes-container">
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--primary">
#           4 495 000 kr
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#                108 m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#           5 rum
#         </div>
# </div>
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--fee">
#           5 996 kr/mån
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--square-meter-price">
#           41 620 kr/m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--">
# </div>
# </div>
# </div>
# <div class="listing-card__description-container listing-card__description--desktop">
# <p class="listing-card__description listing-card__description--two-lines">
#     ** Sjöglimt, insynsfritt, optimal planlösning, låg avgift och solid förening med dolda tillgångar **
#
# Varmt välkomna till charmiga Krysshammarvägen 32! Här finner ni en unik bostad som sällan kommer ut. Den har ett naturligt insynsskydd samt en inglasad balkong i attraktivt solläge. Här kan mag...
#   </p>
# </div>
# <div class="listing-card__labels-container">
# <ul class="hcl-labels-list hcl-labels-list--row-direction">
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--product hcl-label--on-white-background">
#             Plus
#           </span>
# </li>
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Balkong
#           </span>
# </li>
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Hiss
#           </span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </a>
# https://www.hemnet.se/bostad/lagenhet-2rum-huvudsta-solna-kommun-krysshammarvagen-4-19190060
# <a class="js-listing-card-link listing-card" data-target-blank="true" href="https://www.hemnet.se/bostad/lagenhet-2rum-huvudsta-solna-kommun-krysshammarvagen-4-19190060">
# <div class="listing-card__images-container">
# <div class="listing-card__image-container">
# <img alt="Krysshammarvägen 4, Huvudsta, Solna kommun" class="js-lazy-load listing-card__image" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/listing_card/7f/b4/7fb401774ec40811ba3a6b80a1a63a69.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# <div class="listing-card__media-attachments-container">
# </div>
# <div class="listing-card__state-labels-container">
# </div>
# <div class="listing-card__save-button__container">
# <div aria-label="Spara" class="js-save-listing" data-in-beta-authentication-experiment="false" data-listing-id="19190060" data-listing-is-saved="false" data-listing-user-saved="false" data-tracking-category="resultatvy">
# <div class="save-listing-button save-listing-button--only-icon">
# <span class="save-listing-button__unsaved-icon">
# <svg viewbox="0 0 20 18" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M17.906 1.298C15.648-.654 12.16-.36 10 1.901 7.84-.361 4.352-.658 2.094 1.298-.844 3.841-.414 7.986 1.68 10.183l6.851 7.178a2.01 2.01 0 002.937.004l6.852-7.178c2.09-2.197 2.528-6.342-.414-8.889z" fill="#007e47"></path><path d="M2.094 1.298C4.352-.658 7.84-.36 10 1.901c2.16-2.262 5.648-2.555 7.906-.603 2.942 2.547 2.504 6.692.414 8.89l-6.851 7.177a2.01 2.01 0 01-2.938-.004L1.68 10.183c-2.094-2.197-2.524-6.342.414-8.885zm14.605 1.474c-1.511-1.309-3.855-1.12-5.332.426L10 4.632 8.633 3.198C7.164 1.66 4.82 1.463 3.3 2.776c-2 1.732-1.711 4.56-.285 6.054l6.851 7.178c.094.096.172.096.266 0l6.851-7.178c1.414-1.482 1.711-4.326-.285-6.058z" fill="#013a14"></path></g></svg>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="listing-card__information-container">
# <div class="listing-card__information-content">
# <div class="listing-card__header">
# <div class="listing-card__address">
# <h2 class="listing-card__street-address qa-listing-title">
#         Krysshammarvägen 4
#       </h2>
# <div class="listing-card__location">
# <span class="listing-card__property-type-icon">
# <svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><title>Lägenhet</title><desc><span class="svg-icon__fallback-text">Lägenhet</span></desc><path class="svg-icon__shape" d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="listing-card__location-name">
#           Huvudsta, Solna kommun
#         </span>
# </div>
# </div>
# <div class="listing-card__broker-logo">
# <img alt="Mäklarhuset Solna" class="js-lazy-load" data-object-fit="contain" data-src="https://bilder.hemnet.se/images/broker_logo_2/61/dd/61ddb2934eeed5062eb88f3c21abc0d4.png" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# </div>
# </div>
# <div class="listing-card__attributes-container">
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--primary">
#           2 395 000 kr
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#                54,6 m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#           2 rum
#         </div>
# </div>
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--fee">
#           2 359 kr/mån
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--square-meter-price">
#           43 864 kr/m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--">
# </div>
# </div>
# </div>
# <div class="listing-card__description-container listing-card__description--desktop">
# <p class="listing-card__description">
#     - Inglasad balkong, helt utan insyn
# - Lågt belånad förening (lån/kv...
#   </p>
# </div>
# <div class="listing-card__labels-container">
# <ul class="hcl-labels-list hcl-labels-list--row-direction">
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Balkong
#           </span>
# </li>
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Hiss
#           </span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </a>
# https://www.hemnet.se/bostad/lagenhet-3rum-gamla-huvudsta-solna-kommun-polhemsgatan-4-19190220
# <a class="js-listing-card-link listing-card" data-target-blank="true" href="https://www.hemnet.se/bostad/lagenhet-3rum-gamla-huvudsta-solna-kommun-polhemsgatan-4-19190220">
# <div class="listing-card__images-container">
# <div class="listing-card__image-container">
# <img alt="Polhemsgatan 4, Gamla Huvudsta, Solna kommun" class="js-lazy-load listing-card__image" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/listing_card/31/95/31952ad9bd2e918742d42d8c61bf41e1.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# <div class="listing-card__media-attachments-container">
# </div>
# <div class="listing-card__state-labels-container">
# </div>
# <div class="listing-card__save-button__container">
# <div aria-label="Spara" class="js-save-listing" data-in-beta-authentication-experiment="false" data-listing-id="19190220" data-listing-is-saved="false" data-listing-user-saved="false" data-tracking-category="resultatvy">
# <div class="save-listing-button save-listing-button--only-icon">
# <span class="save-listing-button__unsaved-icon">
# <svg viewbox="0 0 20 18" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M17.906 1.298C15.648-.654 12.16-.36 10 1.901 7.84-.361 4.352-.658 2.094 1.298-.844 3.841-.414 7.986 1.68 10.183l6.851 7.178a2.01 2.01 0 002.937.004l6.852-7.178c2.09-2.197 2.528-6.342-.414-8.889z" fill="#007e47"></path><path d="M2.094 1.298C4.352-.658 7.84-.36 10 1.901c2.16-2.262 5.648-2.555 7.906-.603 2.942 2.547 2.504 6.692.414 8.89l-6.851 7.177a2.01 2.01 0 01-2.938-.004L1.68 10.183c-2.094-2.197-2.524-6.342.414-8.885zm14.605 1.474c-1.511-1.309-3.855-1.12-5.332.426L10 4.632 8.633 3.198C7.164 1.66 4.82 1.463 3.3 2.776c-2 1.732-1.711 4.56-.285 6.054l6.851 7.178c.094.096.172.096.266 0l6.851-7.178c1.414-1.482 1.711-4.326-.285-6.058z" fill="#013a14"></path></g></svg>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="listing-card__information-container">
# <div class="listing-card__information-content">
# <div class="listing-card__header">
# <div class="listing-card__address">
# <h2 class="listing-card__street-address qa-listing-title">
#         Polhemsgatan 4
#       </h2>
# <div class="listing-card__location">
# <span class="listing-card__property-type-icon">
# <svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><title>Lägenhet</title><desc><span class="svg-icon__fallback-text">Lägenhet</span></desc><path class="svg-icon__shape" d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="listing-card__location-name">
#           Gamla Huvudsta, Solna kommun
#         </span>
# </div>
# </div>
# <div class="listing-card__broker-logo">
# <img alt="HusmanHagberg Solna" class="js-lazy-load" data-object-fit="contain" data-src="https://bilder.hemnet.se/images/broker_logo_2/b6/56/b656d8b9f26d099a415a7546b5d620a2.png" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# </div>
# </div>
# <div class="listing-card__attributes-container">
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--primary">
#           3 895 000 kr
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#               75
#               <span class="listing-card__attribute--normal-weight">
#                 + 1 m²
#               </span>
# </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#           3 rum
#         </div>
# </div>
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--fee">
#           3 270 kr/mån
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--square-meter-price">
#           51 933 kr/m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--">
# </div>
# </div>
# </div>
# ...
# </div>
# </div>
# <div class="listing-card__state-label-container">
# <div class="listing-label listing-label--state listing-label--highlighted_showing qa-listing-label-state-highlighted_showing">
# <span class="state-label-icon--highlighted_showing"></span>
# <span class="listing-label__text">Sön 16 okt kl 11:15</span>
# </div>
# </div>
# </div>
# <div class="listing-card__save-button__container">
# <div aria-label="Spara" class="js-save-listing" data-in-beta-authentication-experiment="false" data-listing-id="18745686" data-listing-is-saved="false" data-listing-user-saved="false" data-tracking-category="resultatvy">
# <div class="save-listing-button save-listing-button--only-icon">
# <span class="save-listing-button__unsaved-icon">
# <svg viewbox="0 0 20 18" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M17.906 1.298C15.648-.654 12.16-.36 10 1.901 7.84-.361 4.352-.658 2.094 1.298-.844 3.841-.414 7.986 1.68 10.183l6.851 7.178a2.01 2.01 0 002.937.004l6.852-7.178c2.09-2.197 2.528-6.342-.414-8.889z" fill="#007e47"></path><path d="M2.094 1.298C4.352-.658 7.84-.36 10 1.901c2.16-2.262 5.648-2.555 7.906-.603 2.942 2.547 2.504 6.692.414 8.89l-6.851 7.177a2.01 2.01 0 01-2.938-.004L1.68 10.183c-2.094-2.197-2.524-6.342.414-8.885zm14.605 1.474c-1.511-1.309-3.855-1.12-5.332.426L10 4.632 8.633 3.198C7.164 1.66 4.82 1.463 3.3 2.776c-2 1.732-1.711 4.56-.285 6.054l6.851 7.178c.094.096.172.096.266 0l6.851-7.178c1.414-1.482 1.711-4.326-.285-6.058z" fill="#013a14"></path></g></svg>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="listing-card__thumbnails-container qa-listing-thumbnails">
# <img alt="" class="listing-card__thumbnail-image js-lazy-load" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/itemgallery_M/33/3e/333eec2f6c3bb52737467aa69c76d051.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# <img alt="" class="listing-card__thumbnail-image js-lazy-load" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/itemgallery_M/d9/d6/d9d6d753f514a8ef06c6ca5e3f75f98c.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# </div>
# </div>
# <div class="listing-card__information-container">
# <div class="listing-card__information-content">
# <div class="listing-card__header">
# <div class="listing-card__address">
# <h2 class="listing-card__street-address qa-listing-title">
#         Trubadurvägen 3, 2 tr
#       </h2>
# <div class="listing-card__location">
# <span class="listing-card__property-type-icon">
# <svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><title>Lägenhet</title><desc><span class="svg-icon__fallback-text">Lägenhet</span></desc><path class="svg-icon__shape" d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="listing-card__location-name">
#           Västra Skogen, Solna kommun
#         </span>
# </div>
# </div>
# <div class="listing-card__broker-logo">
# <img alt="SkandiaMäklarna Solna" class="js-lazy-load" data-object-fit="contain" data-src="https://bilder.hemnet.se/images/broker_logo_2/63/7c/637c17c40a250ef71084ac34e860d757.jpg" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# </div>
# </div>
# <div class="listing-card__attributes-container">
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--primary">
#           4 450 000 kr
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#                65 m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#           3 rum
#         </div>
# </div>
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--fee">
#           3 521 kr/mån
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--square-meter-price">
#           68 462 kr/m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--">
# </div>
# </div>
# </div>
# <div class="listing-card__description-container listing-card__description--desktop">
# <p class="listing-card__description listing-card__description--six-lines">
#     *ACCEPTERAT PRIS*
#
# Står en stilren, ljus och nyproducerad gaveltrea i  fantastiskt läge  på önskelistan? Då är detta verkligen något för er!
#
# Hela lägenheten genomsyras av en stilren interiör med ekparkett och vitmålade väggar. Vardagsrummet lämnar gott om plats för den generösa soffmöbleringen och två stora fönsterpartier tillför naturligt ljusinsläpp. Vid matplatsen ryms enkelt familjen med ...
#   </p>
# </div>
# <div class="listing-card__labels-container">
# <ul class="hcl-labels-list hcl-labels-list--row-direction">
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--product hcl-label--on-white-background">
#             Premium
#           </span>
# </li>
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Balkong
#           </span>
# </li>
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Hiss
#           </span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </a>
# https://www.hemnet.se/bostad/lagenhet-2rum-vastra-skogen-solna-kommun-armegatan-28,-van-3-18873377
# <a class="js-listing-card-link listing-card" data-target-blank="true" href="https://www.hemnet.se/bostad/lagenhet-2rum-vastra-skogen-solna-kommun-armegatan-28,-van-3-18873377">
# <div class="listing-card__images-container">
# <div class="listing-card__image-container">
# <img alt="Armégatan 28, vån 3!, Västra Skogen, Solna kommun" class="js-lazy-load listing-card__image listing-card__image--big" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/listing_card/39/fd/39fd9c806c74631d1302c017257c4d3e.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# <div class="listing-card__media-attachments-container">
# </div>
# <div class="listing-card__state-labels-container">
# </div>
# <div class="listing-card__save-button__container">
# <div aria-label="Spara" class="js-save-listing" data-in-beta-authentication-experiment="false" data-listing-id="18873377" data-listing-is-saved="false" data-listing-user-saved="false" data-tracking-category="resultatvy">
# <div class="save-listing-button save-listing-button--only-icon">
# <span class="save-listing-button__unsaved-icon">
# <svg viewbox="0 0 20 18" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M17.906 1.298C15.648-.654 12.16-.36 10 1.901 7.84-.361 4.352-.658 2.094 1.298-.844 3.841-.414 7.986 1.68 10.183l6.851 7.178a2.01 2.01 0 002.937.004l6.852-7.178c2.09-2.197 2.528-6.342-.414-8.889z" fill="#007e47"></path><path d="M2.094 1.298C4.352-.658 7.84-.36 10 1.901c2.16-2.262 5.648-2.555 7.906-.603 2.942 2.547 2.504 6.692.414 8.89l-6.851 7.177a2.01 2.01 0 01-2.938-.004L1.68 10.183c-2.094-2.197-2.524-6.342.414-8.885zm14.605 1.474c-1.511-1.309-3.855-1.12-5.332.426L10 4.632 8.633 3.198C7.164 1.66 4.82 1.463 3.3 2.776c-2 1.732-1.711 4.56-.285 6.054l6.851 7.178c.094.096.172.096.266 0l6.851-7.178c1.414-1.482 1.711-4.326-.285-6.058z" fill="#013a14"></path></g></svg>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="listing-card__thumbnails-container qa-listing-thumbnails">
# <img alt="" class="listing-card__thumbnail-image js-lazy-load" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/itemgallery_M/50/26/502698c155e33f6628ffcd95f3146e54.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# <img alt="" class="listing-card__thumbnail-image js-lazy-load" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/itemgallery_M/5a/23/5a2376e438d89104b3826d837e3cf225.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# </div>
# </div>
# <div class="listing-card__information-container">
# <div class="listing-card__information-content">
# <div class="listing-card__header">
# <div class="listing-card__address">
# <h2 class="listing-card__street-address qa-listing-title">
#         Armégatan 28, vån 3!
#       </h2>
# <div class="listing-card__location">
# <span class="listing-card__property-type-icon">
# <svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><title>Lägenhet</title><desc><span class="svg-icon__fallback-text">Lägenhet</span></desc><path class="svg-icon__shape" d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="listing-card__location-name">
#           Västra Skogen, Solna kommun
#         </span>
# </div>
# </div>
# <div class="listing-card__broker-logo">
# <img alt="Länsförsäkringar Fastighetsförmedling Solna" class="js-lazy-load" data-object-fit="contain" data-src="https://bilder.hemnet.se/images/broker_logo_2/73/c6/73c63376473b74a25e13711a82fcae60.png" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# </div>
# </div>
# <div class="listing-card__attributes-container">
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--primary">
#           2 850 000 kr
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#                56,5 m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#           2 rum
#         </div>
# </div>
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--fee">
#           2 865 kr/mån
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--square-meter-price">
#           50 442 kr/m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--">
# </div>
# </div>
# </div>
# <div class="listing-card__description-container listing-card__description--desktop">
# <p class="listing-card__description listing-card__description--six-lines">
#     Accepterat pris! Kontakta ansvarig mäklare för privatvisning.
#
# Fint renoverad tvåa med ett härligt ljusinsläpp!
#
# - Låg månadsavgift inkl. vatten, värme och Comhem basutbud
# - Stambytt &amp; renoverat badrum
# - I föreningen finns gott om parkeringsplatser
# - Fina materialval
# - Insynsskyddat läge
#
# Välkomna till Armégatan 28 och denna fint renoverade tvåa med fint ljusinsläpp!
#
# Går vi in i de...
#   </p>
# </div>
# <div class="listing-card__labels-container">
# <ul class="hcl-labels-list hcl-labels-list--row-direction">
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--product hcl-label--on-white-background">
#             Premium
#           </span>
# </li>
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Balkong
#           </span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </a>
# https://www.hemnet.se/bostad/lagenhet-1rum-huvudsta-solna-kommun-bygatan-21,-2-tr-18828868
# <a class="js-listing-card-link listing-card" data-target-blank="true" href="https://www.hemnet.se/bostad/lagenhet-1rum-huvudsta-solna-kommun-bygatan-21,-2-tr-18828868">
# <div class="listing-card__images-container">
# <div class="listing-card__image-container">
# <img alt="Bygatan 21, 2 tr, Huvudsta, Solna kommun" class="js-lazy-load listing-card__image" data-object-fit="cover" data-src="https://bilder.hemnet.se/images/listing_card/c9/fc/c9fc3a1c7105938cec74087b2499200f.jpg" nopin="nopin" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# <div class="listing-card__media-attachments-container">
# <div class="listing-card__media-attachments-label-container">
# <div class="listing-label listing-label--media_attachment listing-label--video listing-label--icon-only qa-listing-label-media_attachment-video">
# <span class="media-attachment-label-icon--video">
# <i class="fa fa-video-camera"></i>
# </span>
# </div>
# </div>
# </div>
# <div class="listing-card__state-labels-container">
# </div>
# <div class="listing-card__save-button__container">
# <div aria-label="Spara" class="js-save-listing" data-in-beta-authentication-experiment="false" data-listing-id="18828868" data-listing-is-saved="false" data-listing-user-saved="false" data-tracking-category="resultatvy">
# <div class="save-listing-button save-listing-button--only-icon">
# <span class="save-listing-button__unsaved-icon">
# <svg viewbox="0 0 20 18" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M17.906 1.298C15.648-.654 12.16-.36 10 1.901 7.84-.361 4.352-.658 2.094 1.298-.844 3.841-.414 7.986 1.68 10.183l6.851 7.178a2.01 2.01 0 002.937.004l6.852-7.178c2.09-2.197 2.528-6.342-.414-8.889z" fill="#007e47"></path><path d="M2.094 1.298C4.352-.658 7.84-.36 10 1.901c2.16-2.262 5.648-2.555 7.906-.603 2.942 2.547 2.504 6.692.414 8.89l-6.851 7.177a2.01 2.01 0 01-2.938-.004L1.68 10.183c-2.094-2.197-2.524-6.342.414-8.885zm14.605 1.474c-1.511-1.309-3.855-1.12-5.332.426L10 4.632 8.633 3.198C7.164 1.66 4.82 1.463 3.3 2.776c-2 1.732-1.711 4.56-.285 6.054l6.851 7.178c.094.096.172.096.266 0l6.851-7.178c1.414-1.482 1.711-4.326-.285-6.058z" fill="#013a14"></path></g></svg>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="listing-card__information-container">
# <div class="listing-card__information-content">
# <div class="listing-card__header">
# <div class="listing-card__address">
# <h2 class="listing-card__street-address qa-listing-title">
#         Bygatan 21, 2 tr
#       </h2>
# <div class="listing-card__location">
# <span class="listing-card__property-type-icon">
# <svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><title>Lägenhet</title><desc><span class="svg-icon__fallback-text">Lägenhet</span></desc><path class="svg-icon__shape" d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="listing-card__location-name">
#           Huvudsta, Solna kommun
#         </span>
# </div>
# </div>
# <div class="listing-card__broker-logo">
# <img alt="Länsförsäkringar Fastighetsförmedling Solna" class="js-lazy-load" data-object-fit="contain" data-src="https://bilder.hemnet.se/images/broker_logo_2/73/c6/73c63376473b74a25e13711a82fcae60.png" src="https://assets.hemnet.se/assets/images/blank.gif"/>
# </div>
# </div>
# <div class="listing-card__attributes-container">
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--primary">
#           2 550 000 kr
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#                41 m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--primary">
#           1 rum
#         </div>
# </div>
# <div class="listing-card__attributes-row">
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--fee">
#           2 152 kr/mån
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--square-meter-price">
#           62 195 kr/m²
#         </div>
# <div class="listing-card__attribute listing-card__attribute--secondary listing-card__attribute--">
# </div>
# </div>
# </div>
# <div class="listing-card__description-container listing-card__description--desktop">
# <p class="listing-card__description">
#     Välkomna till Bygatan 21 och denna perfekt disponerade etta med all...
#   </p>
# </div>
# <div class="listing-card__labels-container">
# <ul class="hcl-labels-list hcl-labels-list--row-direction">
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Balkong
#           </span>
# </li>
# <li class="hcl-labels-list__label-item">
# <span class="hcl-label hcl-label--feature hcl-label--on-white-background">
#             Hiss
#           </span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </a>

# %% [markdown]
# ---- w lxml (ful encoding) ----

# %%
#not sure why etree gives warning here.. it usually doesn't
dom=etree.HTML(response.content)
dom
# Out:
# <Element html at 0x2c97a8c1300>

# %%
tes=dom.xpath('//*[@id="result"]/ul/li')
tes=dom.xpath('//*[@id="result"]/ul/li/a/div[2]/div/div[1]/div[1]/h2/text()')
tes
# Out:
# ['\n        SlÃ¤ggbacken 7, vÃ¥n 6\n      ',
#  '\n        Storgatan 56\n      ',
#  '\n        KrysshammarvÃ¤gen 30, vÃ¥n 4\n      ',
#  '\n        ArmÃ©gatan 11b\n      ',
#  '\n        Johan Enbergs vÃ¤g 64\n      ',
#  '\n        Storgatan 72A\n      ',
#  '\n        ArmÃ©gatan 11A\n      ',
#  '\n        KrysshammarvÃ¤gen 32, 5tr!\n      ',
#  '\n        KrysshammarvÃ¤gen 4\n      ',
#  '\n        Polhemsgatan 4\n      ',
#  '\n        Storgatan 70B\n      ',
#  '\n        KrysshammarvÃ¤gen 22\n      ',
#  '\n        GÃ¶ran Perssons VÃ¤g 29, 2 tr\n      ',
#  '\n        Jungfrudansen 52\n      ',
#  '\n        Storgatan 72A\n      ',
#  '\n        Jungfrudansen 7\n      ',
#  '\n        Jungfrudansen 50\n      ',
#  '\n        Arvid TydÃ©ns AllÃ© 28, vÃ¥n 4/4\n      ',
#  '\n        ArmÃ©gatan 25, HÃ¶gt upp i huset!\n      ',
#  '\n        ArmÃ©gatan 3,  HÃ¶gt upp i huset!\n      ',
#  '\n        Johan Enbergs vÃ¤g 15, 1 tr\n      ',
#  '\n        Bangatan 1D\n      ',
#  '\n        Arvid TydÃ©ns allÃ© 26\n      ',
#  '\n        Jungfrudansen 42, vÃ¥n 2\n      ',
#  '\n        KristinelundsvÃ¤gen 34, vÃ¥n 1\n      ',
#  '\n        Johan Enbergs vÃ¤g 54B\n      ',
#  '\n        JonstorpsvÃ¤gen 28\n      ',
#  '\n        Johan Enbergs vÃ¤g 9, vÃ¥n 7\n      ',
#  '\n        ArmÃ©gatan 25, vÃ¥n 6\n      ',
#  '\n        Wiboms vÃ¤g 12\n      ',
#  '\n        DiktarvÃ¤gen 8\n      ',
#  '\n        KristinelundsvÃ¤gen 46\n      ',
#  '\n        Jungfrudansen 40, 2 tr\n      ',
#  '\n        Infanterigatan 5\n      ',
#  '\n        Wiboms VÃ¤g 2, 6 tr\n      ',
#  '\n        Infanterigatan 17\n      ',
#  '\n        Polhemsgatan 4, 3 tr\n      ',
#  '\n        Johan Enbergs vÃ¤g 28, vÃ¥n 5\n      ',
#  '\n        Jungfrudansen 12, 2 tr\n      ',
#  '\n        Huvudstagatan 14A, 3tr\n      ',
#  '\n        Oskarsrogatan 5, 7tr\n      ',
#  '\n        Storgatan 62C\n      ',
#  '\n        Infanterigatan 9\n      ',
#  '\n        Kapellgatan 18 / Ingentingsgatan 14\n      ',
#  '\n        Infanterigatan 25\n      ',
#  '\n        ArmÃ©gatan 5, HÃ\x96GST UPP I HUSET!\n      ',
#  '\n        Jungfrudansen 44\n      ',
#  '\n        Kapellgatan 20, 2 tr\n      ',
#  '\n        Bygatan 25\n      ',
#  '\n        TrubadurvÃ¤gen 3, 2 tr\n      ',
#  '\n        ArmÃ©gatan 28, vÃ¥n 3!\n      ']
