# %%
import pandas as pd
from lxml import etree
import requests

# %% [markdown]
# ---- using HTML response ----

# %%
url = "https://www.hemnet.se/bostader"
params= {
    'housing_form_groups':'apartments',
    'location_ids':'473498',
    'item_types':'bostadsratt'
}
payload={}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'
}

response = requests.request("GET", url, headers=headers, data=payload, params=params)
response.url
# Out:
# 'https://www.hemnet.se/bostader?housing_form_groups=apartments&location_ids=473498&item_types=bostadsratt'

# %% [markdown]
# --------- w beautiful soup ------------

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %% [markdown]
# --- by using the jsons in the script tags we can get locations and listings ----

# %%
import json

#find all script tags with json data
script_list=soup.find_all("script",type="application/ld+json")

#json.loads(script_list[1].text)
#type(script_list)

# %%
#get the two jsons we want - place and item list
place_json=json.loads(script_list[1].text)
item_list_json=json.loads(script_list[2].text)

# %%
#put item list json into a df
item_list_df=pd.json_normalize(item_list_json['itemListElement'])
#item_list_df

# %%
#and location json into another df
place_df=pd.json_normalize(place_json)
place_df
# Out:
#             @context  @type address.addressLocality address.addressRegion  \
# 0  http://schema.org  Place                Huvudsta        Stockholms län
#
#   address.addressCountry
# 0                     SE

# %%
#make new col with location/region for the list items
new_cols={'addressLocality':place_df.iloc[0]['address.addressLocality'],'addressRegion':place_df.iloc[0]['address.addressRegion']}
item_list_df.assign(**new_cols)
# Out:
#        @type                                                url  position  \
# 0   ListItem  https://www.hemnet.se/bostad/lagenhet-3rum-sol...         1
# 1   ListItem  https://www.hemnet.se/bostad/lagenhet-3rum-vas...         2
# 2   ListItem  https://www.hemnet.se/bostad/lagenhet-3rum-vas...         3
# 3   ListItem  https://www.hemnet.se/bostad/lagenhet-4rum-huv...         4
# 4   ListItem  https://www.hemnet.se/bostad/lagenhet-2,5rum-h...         5
# 5   ListItem  https://www.hemnet.se/bostad/lagenhet-3rum-huv...         6
# 6   ListItem  https://www.hemnet.se/bostad/lagenhet-5rum-vas...         7
# 7   ListItem  https://www.hemnet.se/bostad/lagenhet-1,5rum-h...         8
# 8   ListItem  https://www.hemnet.se/bostad/lagenhet-2rum-vas...         9
# 9   ListItem  https://www.hemnet.se/bostad/lagenhet-5rum-sol...        10
# 10  ListItem  https://www.hemnet.se/bostad/lagenhet-2rum-huv...        11
# 11  ListItem  https://www.hemnet.se/bostad/lagenhet-3rum-gam...        12
# 12  ListItem  https://www.hemnet.se/bostad/lagenhet-1rum-huv...        13
# 13  ListItem  https://www.hemnet.se/bostad/lagenhet-2rum-huv...        14
# 14  ListItem  https://www.hemnet.se/bostad/lagenhet-3rum-huv...        15
# 15  ListItem  https://www.hemnet.se/bostad/lagenhet-2rum-jun...        16
# 16  ListItem  https://www.hemnet.se/bostad/lagenhet-4rum-huv...        17
# 17  ListItem  https://www.hemnet.se/bostad/lagenhet-1rum-huv...        18
# 18  ListItem  https://www.hemnet.se/bostad/lagenhet-3rum-huv...        19
# 19  ListItem  https://www.hemnet.se/bostad/lagenhet-4rum-vas...        20
# 20  ListItem  https://www.hemnet.se/bostad/lagenhet-3rum-huv...        21
# 21  ListItem  https://www.hemnet.se/bostad/lagenhet-2rum-vas...        22
# 22  ListItem  https://www.hemnet.se/bostad/lagenhet-2rum-vas...        23
# 23  ListItem  https://www.hemnet.se/bostad/lagenhet-1rum-sol...        24
# 24  ListItem  https://www.hemnet.se/bostad/lagenhet-2rum-huv...        25
# 25  ListItem  https://www.hemnet.se/bostad/lagenhet-4rum-huv...        26
# 26  ListItem  https://www.hemnet.se/bostad/lagenhet-4rum-vas...        27
# 27  ListItem  https://www.hemnet.se/bostad/lagenhet-4rum-huv...        28
# 28  ListItem  https://www.hemnet.se/bostad/lagenhet-3rum-vas...        29
# 29  ListItem  https://www.hemnet.se/bostad/lagenhet-2rum-huv...        30
# 30  ListItem  https://www.hemnet.se/bostad/lagenhet-2rum-huv...        31
# 31  ListItem  https://www.hemnet.se/bostad/lagenhet-2rum-vas...        32
# 32  ListItem  https://www.hemnet.se/bostad/lagenhet-1rum-huv...        33
# 33  ListItem  https://www.hemnet.se/bostad/lagenhet-3rum-jun...        34
# 34  ListItem  https://www.hemnet.se/bostad/lagenhet-1rum-huv...        35
# 35  ListItem  https://www.hemnet.se/bostad/lagenhet-3rum-vas...        36
# 36  ListItem  https://www.hemnet.se/bostad/lagenhet-1,5rum-v...        37
# 37  ListItem  https://www.hemnet.se/bostad/lagenhet-4rum-gam...        38
# 38  ListItem  https://www.hemnet.se/bostad/lagenhet-2rum-vas...        39
# 39  ListItem  https://www.hemnet.se/bostad/lagenhet-3rum-huv...        40
# 40  ListItem  https://www.hemnet.se/bostad/lagenhet-4rum-huv...        41
# 41  ListItem  https://www.hemnet.se/bostad/lagenhet-2rum-sol...        42
# 42  ListItem  https://www.hemnet.se/bostad/lagenhet-3rum-huv...        43
# 43  ListItem  https://www.hemnet.se/bostad/lagenhet-1rum-huv...        44
# 44  ListItem  https://www.hemnet.se/bostad/lagenhet-1rum-vas...        45
# 45  ListItem  https://www.hemnet.se/bostad/lagenhet-4rum-vas...        46
# 46  ListItem  https://www.hemnet.se/bostad/lagenhet-5rum-sol...        47
# 47  ListItem  https://www.hemnet.se/bostad/lagenhet-1,5rum-v...        48
# 48  ListItem  https://www.hemnet.se/bostad/lagenhet-2rum-huv...        49
# 49  ListItem  https://www.hemnet.se/bostad/lagenhet-3rum-vas...        50
#
#    addressLocality   addressRegion
# 0         Huvudsta  Stockholms län
# 1         Huvudsta  Stockholms län
# 2         Huvudsta  Stockholms län
# 3         Huvudsta  Stockholms län
# 4         Huvudsta  Stockholms län
# 5         Huvudsta  Stockholms län
# 6         Huvudsta  Stockholms län
# 7         Huvudsta  Stockholms län
# 8         Huvudsta  Stockholms län
# 9         Huvudsta  Stockholms län
# 10        Huvudsta  Stockholms län
# 11        Huvudsta  Stockholms län
# 12        Huvudsta  Stockholms län
# 13        Huvudsta  Stockholms län
# 14        Huvudsta  Stockholms län
# 15        Huvudsta  Stockholms län
# 16        Huvudsta  Stockholms län
# 17        Huvudsta  Stockholms län
# 18        Huvudsta  Stockholms län
# 19        Huvudsta  Stockholms län
# 20        Huvudsta  Stockholms län
# 21        Huvudsta  Stockholms län
# 22        Huvudsta  Stockholms län
# 23        Huvudsta  Stockholms län
# 24        Huvudsta  Stockholms län
# 25        Huvudsta  Stockholms län
# 26        Huvudsta  Stockholms län
# 27        Huvudsta  Stockholms län
# 28        Huvudsta  Stockholms län
# 29        Huvudsta  Stockholms län
# 30        Huvudsta  Stockholms län
# 31        Huvudsta  Stockholms län
# 32        Huvudsta  Stockholms län
# 33        Huvudsta  Stockholms län
# 34        Huvudsta  Stockholms län
# 35        Huvudsta  Stockholms län
# 36        Huvudsta  Stockholms län
# 37        Huvudsta  Stockholms län
# 38        Huvudsta  Stockholms län
# 39        Huvudsta  Stockholms län
# 40        Huvudsta  Stockholms län
# 41        Huvudsta  Stockholms län
# 42        Huvudsta  Stockholms län
# 43        Huvudsta  Stockholms län
# 44        Huvudsta  Stockholms län
# 45        Huvudsta  Stockholms län
# 46        Huvudsta  Stockholms län
# 47        Huvudsta  Stockholms län
# 48        Huvudsta  Stockholms län
# 49        Huvudsta  Stockholms län
